# %% [markdown]
# # Problema de designação de pessoas **I** para instrumentos **J** e vozes **L** no dia **K**
# ---
#
# ##  i - Conjunto de pessoas
# ##  J - Conjunto de instrumentos
# ##  k - Conjunto de dias
# ##  l - Conjunto de vozes
#
# ---
#
# * Mij = Matriz Binária - Pessoa I toca Instrumento J
#
# * Sil = Matriz Binária - Pessoa I toca canta na posição L
#
# * PMj = Peso de cada instrumento J
# * PSl = Peso de cada voz L
#
# * Dk = Peso de cada dia K
#
# ### Solução
# * Xijk - Matriz Binária no R3
# * Yilk - Matriz Binária no R3
# * Zik -  Matriz binária no R2
#
# * **Se Xijk = 1 => A pessoa "i" tocará o instrumento 'j' no dia 'k'**
#
# * Se Yijl = 1 => A pessoa "i" cantará na posição 'l' no dia 'k'
#
# * **Se Xijk = 0 => A pessoa "i" não tocará o instrumento 'j' no dia 'k'**
#
# * Se Yijl = 0 => A pessoa "i" não cantará na posição 'l' no dia 'k'
#
# * **Somatório em i de Xijk <= 1 -  Um instrumento 'j' só pode ser tocado por uma pessoa 'i' em um dia 'k'**
#
# * Somatório em i de Yilk <= 1 - Uma voz 'l' só pode ser cantada por uma pessoa 'i' em um dia 'k'
#
# * **Somatório em 'j' de Xijk <= 1 - A pessoa "i" tocará somente um instrumento instrumento 'j' no dia 'k'**
#
# * Somatório em 'l' de Yilk <= 1 - A pessoa "i" cantará somente em uma posição "l" no dia "k"
#
# * **Zik - Pessoa i participa no dia k**
# * **Zik = 0 se Xijk e yilk = 0**
# * **Zik = 1 se Xijk ou yilk = 1**
#
#
# * **Zik + Zi(k+1) + Zi(k+2) + Zi(k+4) <= 2 para todo i - A pessoa "i" não participará mais do que dois dias seguidos.**
#
#
# * **Xijk = 0 se PMij = 0**
# * Yilk = 0 se PSil = 0
#
#
# * Maximize Xijk * Mij * PMj * Dk + Yilk * Sil * PSl * Dk

# %%
import pandas as pd

file_name = 'Dados Louvor Shalom.xlsx'

sheets_dict = pd.read_excel(file_name, sheet_name=['Instrumento', 'Peso dos Instrumentos', 'Peso dos Dias','Disponibilidade', 'Dias por Mês', 'Vozes'])

# Acesse cada sheet pelo nome
#Dias por Mês
P = sheets_dict['Instrumento'].set_index('Pessoas')
L = sheets_dict['Peso dos Instrumentos'].set_index('Instrumentos').squeeze()
D = pd.Series(sheets_dict['Peso dos Dias']['Peso'])

Disp = sheets_dict['Disponibilidade']
DPM = sheets_dict['Dias por Mês'].set_index('Pessoas')
V = sheets_dict['Vozes'].set_index('Pessoas')

# %%
from pulp import *

days = 2

# Definir o problema
prob = LpProblem("Alocacao_de_Musicos", LpMaximize)

# Variáveis de decisão
X = LpVariable.dicts("X", (P.index, P.columns, D.index), cat='Binary')

# Função objetivo
prob += lpSum([X[i][j][k] * P.loc[i, j] * L[j] * D[k] for i in P.index for j in P.columns for k in D.index])

# Restrições
for j in P.columns:
    for k in D.index:
        prob += lpSum([X[i][j][k] for i in P.index]) <= 1

for i in P.index:
    for k in D.index:
        prob += lpSum([X[i][j][k] for j in P.columns]) <= 1

for i in P.index:
    for k in range(len(D.index) - 3):
        prob += lpSum([X[i][j][D.index[k]] + X[i][j][D.index[k+1]] + X[i][j][D.index[k+2]] + X[i][j][D.index[k+2]] for j in P.columns]) <= DPM['Quantidade'][i]

for i in P.index:
    for j in P.columns:
        for k in D.index:
            if P.loc[i, j] == 0:
                prob += X[i][j][k] == 0

# Resolver o problema
prob.solve()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/hmbarros/.local/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/21117631e0cd4dc999acc74fb9e9447f-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /tmp/21117631e0cd4dc999acc74fb9e9447f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1355 COLUMNS
# At line 9906 RHS
# At line 11257 BOUNDS
# At line 12428 ENDATA
# Problem MODEL has 1350 rows, 1170 columns and 5911 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1326 - 0.00 seconds
# Cgl0002I 871 variables fixed
# Cgl0003I 0 fixed, 0 tightened bounds, 92 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 66 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 39 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 33 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 14 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 9 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 4 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 3 strengthened rows, 0 substitutions
# Cgl0004I processed model has 241 rows, 271 columns (271 integer (271 of which binary)) and 1234 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 69 integers unsatisfied sum - 18.5937
# Cbc0038I Pass   1: suminf.    0.66667 (2) obj. -1199.33 iterations 121
# Cbc0038I Solution found of -1186
# Cbc0038I Rounding solution of -1251 is better than previous of -1186
#
# Cbc0038I Before mini branch and bound, 202 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 241 rows 271 columns, reduced to 98 rows 60 columns
# Cbc0038I Mini branch and bound improved solution from -1251 to -1316 (0.06 seconds)
# Cbc0038I Round again with cutoff of -1317.9
# Cbc0038I Pass   2: suminf.    2.37998 (5) obj. -1317.9 iterations 109
# Cbc0038I Pass   3: suminf.    2.37998 (5) obj. -1317.9 iterations 16
# Cbc0038I Pass   4: suminf.    0.50000 (1) obj. -1318.5 iterations 80
# Cbc0038I Pass   5: suminf.    0.37998 (1) obj. -1317.9 iterations 89
# Cbc0038I Pass   6: suminf.    0.50000 (1) obj. -1318.5 iterations 73
# Cbc0038I Pass   7: suminf.    3.60009 (10) obj. -1317.9 iterations 172
# Cbc0038I Pass   8: suminf.    0.37998 (1) obj. -1317.9 iterations 110
# Cbc0038I Pass   9: suminf.    0.37998 (1) obj. -1317.9 iterations 1
# Cbc0038I Pass  10: suminf.    0.50000 (1) obj. -1318.5 iterations 77
# Cbc0038I Pass  11: suminf.    7.30831 (29) obj. -1317.9 iterations 138
# Cbc0038I Pass  12: suminf.    3.72498 (9) obj. -1317.9 iterations 64
# Cbc0038I Pass  13: suminf.    3.72498 (9) obj. -1317.9 iterations 14
# Cbc0038I Pass  14: suminf.    2.72498 (7) obj. -1317.9 iterations 1
# Cbc0038I Pass  15: suminf.    0.67493 (3) obj. -1317.9 iterations 158
# Cbc0038I Pass  16: suminf.    0.67493 (3) obj. -1317.9 iterations 46
# Cbc0038I Pass  17: suminf.    0.68999 (2) obj. -1317.9 iterations 134
# Cbc0038I Pass  18: suminf.    0.68999 (2) obj. -1317.9 iterations 2
# Cbc0038I Pass  19: suminf.    0.00000 (0) obj. -1321 iterations 62
# Cbc0038I Solution found of -1321
# Cbc0038I Before mini branch and bound, 159 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 241 rows 271 columns, reduced to 145 rows 110 columns - 18 fixed gives 69, 51 - ok now
# Cbc0038I Full problem 241 rows 271 columns, reduced to 65 rows 48 columns
# Cbc0038I Mini branch and bound did not improve solution (0.08 seconds)
# Cbc0038I Round again with cutoff of -1322.8
# Cbc0038I Pass  20: suminf.    5.31494 (24) obj. -1322.8 iterations 47
# Cbc0038I Pass  21: suminf.    3.81494 (17) obj. -1322.8 iterations 43
# Cbc0038I Pass  22: suminf.    3.79294 (25) obj. -1322.8 iterations 6
# Cbc0038I Pass  23: suminf.    3.79294 (25) obj. -1322.8 iterations 4
# Cbc0038I Pass  24: suminf.    9.12649 (33) obj. -1322.8 iterations 84
# Cbc0038I Pass  25: suminf.    3.43994 (9) obj. -1322.8 iterations 51
# Cbc0038I Pass  26: suminf.    3.43994 (9) obj. -1322.8 iterations 8
# Cbc0038I Pass  27: suminf.    1.25994 (9) obj. -1322.8 iterations 33
# Cbc0038I Pass  28: suminf.    1.25994 (9) obj. -1322.8 iterations 24
# Cbc0038I Pass  29: suminf.    2.93331 (8) obj. -1322.8 iterations 138
# Cbc0038I Pass  30: suminf.    1.64665 (6) obj. -1322.8 iterations 15
# Cbc0038I Pass  31: suminf.    1.64665 (6) obj. -1322.8 iterations 7
# Cbc0038I Pass  32: suminf.   14.30141 (52) obj. -1322.8 iterations 122
# Cbc0038I Pass  33: suminf.    6.85187 (21) obj. -1322.8 iterations 85
# Cbc0038I Pass  34: suminf.    5.46645 (18) obj. -1322.8 iterations 10
# Cbc0038I Pass  35: suminf.    5.13312 (19) obj. -1322.8 iterations 1
# Cbc0038I Pass  36: suminf.    5.52000 (18) obj. -1322.8 iterations 80
# Cbc0038I Pass  37: suminf.    4.63582 (17) obj. -1322.8 iterations 56
# Cbc0038I Pass  38: suminf.    4.63582 (17) obj. -1322.8 iterations 15
# Cbc0038I Pass  39: suminf.    4.63582 (17) obj. -1322.8 iterations 3
# Cbc0038I Pass  40: suminf.    5.24249 (15) obj. -1322.8 iterations 64
# Cbc0038I Pass  41: suminf.    2.07995 (5) obj. -1322.8 iterations 36
# Cbc0038I Pass  42: suminf.    2.07995 (5) obj. -1322.8 iterations 41
# Cbc0038I Pass  43: suminf.    1.35998 (5) obj. -1322.8 iterations 178
# Cbc0038I Pass  44: suminf.    1.35998 (5) obj. -1322.8 iterations 3
# Cbc0038I Pass  45: suminf.    1.35998 (5) obj. -1322.8 iterations 11
# Cbc0038I Pass  46: suminf.    0.10667 (1) obj. -1322.8 iterations 76
# Cbc0038I Solution found of -1326
# Cbc0038I Before mini branch and bound, 142 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.11 seconds)
# Cbc0038I After 0.11 seconds - Feasibility pump exiting with objective of -1326 - took 0.07 seconds
# Cbc0012I Integer solution of -1326 found by feasibility pump after 0 iterations and 0 nodes (0.11 seconds)
# Cbc0001I Search completed - best objective -1326, took 0 iterations and 0 nodes (0.11 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -1326 to -1326
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1326.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.10
# Time (Wallclock seconds):       0.12
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.11   (Wallclock seconds):       0.13
# 1

# %%
# Imprimir o status da solução
print("Status:", LpStatus[prob.status])

# Imprimir o valor da função objetivo
print("Valor da função objetivo =", value(prob.objective))

# Dicionário para armazenar os resultados
resultados = {}

# Iterar sobre cada variável de decisão
for v in prob.variables():
    if v.varValue != 0:
        # Extrair o nome da pessoa, o instrumento e o dia
        _, pessoa, instrumento, dia = v.name.split("_", 3)

        # Se o dia ainda não está no dicionário, adicione-o
        if dia not in resultados:
            resultados[dia] = {}

        # Adicione a pessoa e o instrumento ao dia correspondente
        resultados[dia][instrumento] = pessoa

print(resultados)
df = pd.DataFrame(columns=P.columns, index=sheets_dict['Peso dos Dias']['Dias'])

# Preencher o DataFrame com os resultados
for dia in resultados:
    for instrumento in resultados[dia]:
        df.loc[sheets_dict['Peso dos Dias']['Dias'][int(dia)], instrumento] = resultados[dia][instrumento]

# Substituir NaN por ''
df = df.fillna('')

if not pd.api.types.is_datetime64_any_dtype(df.index):
    df.index = pd.to_datetime(df.index, origin='1899-12-30', unit='D')

# Formatar o índice para o formato brasileiro
df.index = df.index.strftime('%d/%m/%Y')

df
# Out:
# Status: Optimal
# Valor da função objetivo = 1326.0
# {'11': {'Teclado': 'Bernardo', 'Bateria': 'Lucas', 'Guitarra': 'Osvaldo', 'Baixo': 'Rafael', 'Violão': 'Ricardo'}, '2': {'Teclado': 'Bernardo', 'Baixo': 'Gabriel', 'Bateria': 'Lucas', 'Guitarra': 'Osvaldo', 'Violão': 'Ricardo'}, '5': {'Teclado': 'Bernardo', 'Guitarra': 'Enzo', 'Bateria': 'Lucas', 'Violão': 'Osvaldo', 'Baixo': 'Ricardo'}, '8': {'Teclado': 'Bernardo', 'Guitarra': 'Daniel', 'Bateria': 'Lucas', 'Violão': 'Osvaldo', 'Baixo': 'Ricardo'}, '1': {'Baixo': 'Daniel', 'Guitarra': 'Enzo', 'Bateria': 'Marcela', 'Violão': 'Osvaldo', 'Teclado': 'Vinicius'}, '0': {'Guitarra': 'Daniel', 'Baixo': 'Enzo', 'Teclado': 'Henrique', 'Bateria': 'Israel', 'Violão': 'Ricardo'}, '4': {'Guitarra': 'Daniel', 'Violão': 'Henrique', 'Bateria': 'Marcela', 'Baixo': 'Osvaldo', 'Teclado': 'Vinicius'}, '9': {'Guitarra': 'Enzo', 'Baixo': 'Gabriel', 'Bateria': 'Henrique', 'Violão': 'Osvaldo', 'Teclado': 'Vinicius'}, '6': {'Baixo': 'Gabriel', 'Bateria': 'Henrique', 'Guitarra': 'Osvaldo', 'Violão': 'Rafael', 'Teclado': 'Vinicius'}, '10': {'Baixo': 'Henrique', 'Bateria': 'Marcela', 'Guitarra': 'Osvaldo', 'Violão': 'Ricardo', 'Teclado': 'Vinicius'}, '3': {'Bateria': 'Henrique', 'Guitarra': 'Osvaldo', 'Violão': 'Rafael', 'Baixo': 'Ricardo', 'Teclado': 'Vinicius'}, '12': {'Violão': 'Henrique', 'Bateria': 'Marcela', 'Guitarra': 'Osvaldo', 'Baixo': 'Ricardo', 'Teclado': 'Vinicius'}, '7': {'Violão': 'Henrique', 'Bateria': 'Marcela', 'Guitarra': 'Osvaldo', 'Baixo': 'Ricardo', 'Teclado': 'Vinicius'}}
#              Bateria     Baixo   Teclado    Violão Guitarra
# Dias
# 14/01/2024    Israel      Enzo  Henrique   Ricardo   Daniel
# 21/01/2024   Marcela    Daniel  Vinicius   Osvaldo     Enzo
# 28/01/2024     Lucas   Gabriel  Bernardo   Ricardo  Osvaldo
# 04/02/2024  Henrique   Ricardo  Vinicius    Rafael  Osvaldo
# 11/02/2024   Marcela   Osvaldo  Vinicius  Henrique   Daniel
# 18/02/2024     Lucas   Ricardo  Bernardo   Osvaldo     Enzo
# 25/02/2024  Henrique   Gabriel  Vinicius    Rafael  Osvaldo
# 03/03/2024   Marcela   Ricardo  Vinicius  Henrique  Osvaldo
# 10/03/2024     Lucas   Ricardo  Bernardo   Osvaldo   Daniel
# 17/03/2024  Henrique   Gabriel  Vinicius   Osvaldo     Enzo
# 24/03/2024   Marcela  Henrique  Vinicius   Ricardo  Osvaldo
# 31/03/2024     Lucas    Rafael  Bernardo   Ricardo  Osvaldo
# 07/04/2024   Marcela   Ricardo  Vinicius  Henrique  Osvaldo

# %%
prob.variables()
# Out:
# [X_Ariane_Baixo_0,
#  X_Ariane_Baixo_1,
#  X_Ariane_Baixo_10,
#  X_Ariane_Baixo_11,
#  X_Ariane_Baixo_12,
#  X_Ariane_Baixo_2,
#  X_Ariane_Baixo_3,
#  X_Ariane_Baixo_4,
#  X_Ariane_Baixo_5,
#  X_Ariane_Baixo_6,
#  X_Ariane_Baixo_7,
#  X_Ariane_Baixo_8,
#  X_Ariane_Baixo_9,
#  X_Ariane_Bateria_0,
#  X_Ariane_Bateria_1,
#  X_Ariane_Bateria_10,
#  X_Ariane_Bateria_11,
#  X_Ariane_Bateria_12,
#  X_Ariane_Bateria_2,
#  X_Ariane_Bateria_3,
#  X_Ariane_Bateria_4,
#  X_Ariane_Bateria_5,
#  X_Ariane_Bateria_6,
#  X_Ariane_Bateria_7,
#  X_Ariane_Bateria_8,
#  X_Ariane_Bateria_9,
#  X_Ariane_Guitarra_0,
#  X_Ariane_Guitarra_1,
#  X_Ariane_Guitarra_10,
#  X_Ariane_Guitarra_11,
#  X_Ariane_Guitarra_12,
#  X_Ariane_Guitarra_2,
#  X_Ariane_Guitarra_3,
#  X_Ariane_Guitarra_4,
#  X_Ariane_Guitarra_5,
#  X_Ariane_Guitarra_6,
#  X_Ariane_Guitarra_7,
#  X_Ariane_Guitarra_8,
#  X_Ariane_Guitarra_9,
#  X_Ariane_Teclado_0,
#  X_Ariane_Teclado_1,
#  X_Ariane_Teclado_10,
#  X_Ariane_Teclado_11,
#  X_Ariane_Teclado_12,
#  X_Ariane_Teclado_2,
#  X_Ariane_Teclado_3,
#  X_Ariane_Teclado_4,
#  X_Ariane_Teclado_5,
#  X_Ariane_Teclado_6,
#  X_Ariane_Teclado_7,
#  X_Ariane_Teclado_8,
#  X_Ariane_Teclado_9,
#  X_Ariane_Violão_0,
#  X_Ariane_Violão_1,
#  X_Ariane_Violão_10,
#  X_Ariane_Violão_11,
#  X_Ariane_Violão_12,
#  X_Ariane_Violão_2,
#  X_Ariane_Violão_3,
#  X_Ariane_Violão_4,
#  X_Ariane_Violão_5,
#  X_Ariane_Violão_6,
#  X_Ariane_Violão_7,
#  X_Ariane_Violão_8,
#  X_Ariane_Violão_9,
#  X_Bernardo_Baixo_0,
#  X_Bernardo_Baixo_1,
#  X_Bernardo_Baixo_10,
#  X_Bernardo_Baixo_11,
#  X_Bernardo_Baixo_12,
#  X_Bernardo_Baixo_2,
#  X_Bernardo_Baixo_3,
#  X_Bernardo_Baixo_4,
#  X_Bernardo_Baixo_5,
#  X_Bernardo_Baixo_6,
#  X_Bernardo_Baixo_7,
#  X_Bernardo_Baixo_8,
#  X_Bernardo_Baixo_9,
#  X_Bernardo_Bateria_0,
#  X_Bernardo_Bateria_1,
#  X_Bernardo_Bateria_10,
#  X_Bernardo_Bateria_11,
#  X_Bernardo_Bateria_12,
#  X_Bernardo_Bateria_2,
#  X_Bernardo_Bateria_3,
#  X_Bernardo_Bateria_4,
#  X_Bernardo_Bateria_5,
#  X_Bernardo_Bateria_6,
#  X_Bernardo_Bateria_7,
#  X_Bernardo_Bateria_8,
#  X_Bernardo_Bateria_9,
#  X_Bernardo_Guitarra_0,
#  X_Bernardo_Guitarra_1,
#  X_Bernardo_Guitarra_10,
#  X_Bernardo_Guitarra_11,
#  X_Bernardo_Guitarra_12,
#  X_Bernardo_Guitarra_2,
#  X_Bernardo_Guitarra_3,
#  X_Bernardo_Guitarra_4,
#  X_Bernardo_Guitarra_5,
#  X_Bernardo_Guitarra_6,
#  X_Bernardo_Guitarra_7,
#  X_Bernardo_Guitarra_8,
#  X_Bernardo_Guitarra_9,
#  X_Bernardo_Teclado_0,
#  X_Bernardo_Teclado_1,
#  X_Bernardo_Teclado_10,
#  X_Bernardo_Teclado_11,
#  X_Bernardo_Teclado_12,
#  X_Bernardo_Teclado_2,
#  X_Bernardo_Teclado_3,
#  X_Bernardo_Teclado_4,
#  X_Bernardo_Teclado_5,
#  X_Bernardo_Teclado_6,
#  X_Bernardo_Teclado_7,
#  X_Bernardo_Teclado_8,
#  X_Bernardo_Teclado_9,
#  X_Bernardo_Violão_0,
#  X_Bernardo_Violão_1,
#  X_Bernardo_Violão_10,
#  X_Bernardo_Violão_11,
#  X_Bernardo_Violão_12,
#  X_Bernardo_Violão_2,
#  X_Bernardo_Violão_3,
#  X_Bernardo_Violão_4,
#  X_Bernardo_Violão_5,
#  X_Bernardo_Violão_6,
#  X_Bernardo_Violão_7,
#  X_Bernardo_Violão_8,
#  X_Bernardo_Violão_9,
#  X_Dani_Voz_Baixo_0,
#  X_Dani_Voz_Baixo_1,
#  X_Dani_Voz_Baixo_10,
#  X_Dani_Voz_Baixo_11,
#  X_Dani_Voz_Baixo_12,
#  X_Dani_Voz_Baixo_2,
#  X_Dani_Voz_Baixo_3,
#  X_Dani_Voz_Baixo_4,
#  X_Dani_Voz_Baixo_5,
#  X_Dani_Voz_Baixo_6,
#  X_Dani_Voz_Baixo_7,
#  X_Dani_Voz_Baixo_8,
#  X_Dani_Voz_Baixo_9,
#  X_Dani_Voz_Bateria_0,
#  X_Dani_Voz_Bateria_1,
#  X_Dani_Voz_Bateria_10,
#  X_Dani_Voz_Bateria_11,
#  X_Dani_Voz_Bateria_12,
#  X_Dani_Voz_Bateria_2,
#  X_Dani_Voz_Bateria_3,
#  X_Dani_Voz_Bateria_4,
#  X_Dani_Voz_Bateria_5,
#  X_Dani_Voz_Bateria_6,
#  X_Dani_Voz_Bateria_7,
#  X_Dani_Voz_Bateria_8,
#  X_Dani_Voz_Bateria_9,
#  X_Dani_Voz_Guitarra_0,
#  X_Dani_Voz_Guitarra_1,
#  X_Dani_Voz_Guitarra_10,
#  X_Dani_Voz_Guitarra_11,
#  X_Dani_Voz_Guitarra_12,
#  X_Dani_Voz_Guitarra_2,
#  X_Dani_Voz_Guitarra_3,
#  X_Dani_Voz_Guitarra_4,
#  X_Dani_Voz_Guitarra_5,
#  X_Dani_Voz_Guitarra_6,
#  X_Dani_Voz_Guitarra_7,
#  X_Dani_Voz_Guitarra_8,
#  X_Dani_Voz_Guitarra_9,
#  X_Dani_Voz_Teclado_0,
#  X_Dani_Voz_Teclado_1,
#  X_Dani_Voz_Teclado_10,
#  X_Dani_Voz_Teclado_11,
#  X_Dani_Voz_Teclado_12,
#  X_Dani_Voz_Teclado_2,
#  X_Dani_Voz_Teclado_3,
#  X_Dani_Voz_Teclado_4,
#  X_Dani_Voz_Teclado_5,
#  X_Dani_Voz_Teclado_6,
#  X_Dani_Voz_Teclado_7,
#  X_Dani_Voz_Teclado_8,
#  X_Dani_Voz_Teclado_9,
#  X_Dani_Voz_Violão_0,
#  X_Dani_Voz_Violão_1,
#  X_Dani_Voz_Violão_10,
#  X_Dani_Voz_Violão_11,
#  X_Dani_Voz_Violão_12,
#  X_Dani_Voz_Violão_2,
#  X_Dani_Voz_Violão_3,
#  X_Dani_Voz_Violão_4,
#  X_Dani_Voz_Violão_5,
#  X_Dani_Voz_Violão_6,
#  X_Dani_Voz_Violão_7,
#  X_Dani_Voz_Violão_8,
#  X_Dani_Voz_Violão_9,
#  X_Daniel_Baixo_0,
#  X_Daniel_Baixo_1,
#  X_Daniel_Baixo_10,
#  X_Daniel_Baixo_11,
#  X_Daniel_Baixo_12,
#  X_Daniel_Baixo_2,
#  X_Daniel_Baixo_3,
#  X_Daniel_Baixo_4,
#  X_Daniel_Baixo_5,
#  X_Daniel_Baixo_6,
#  X_Daniel_Baixo_7,
#  X_Daniel_Baixo_8,
#  X_Daniel_Baixo_9,
#  X_Daniel_Bateria_0,
#  X_Daniel_Bateria_1,
#  X_Daniel_Bateria_10,
#  X_Daniel_Bateria_11,
#  X_Daniel_Bateria_12,
#  X_Daniel_Bateria_2,
#  X_Daniel_Bateria_3,
#  X_Daniel_Bateria_4,
#  X_Daniel_Bateria_5,
#  X_Daniel_Bateria_6,
#  X_Daniel_Bateria_7,
#  X_Daniel_Bateria_8,
#  X_Daniel_Bateria_9,
#  X_Daniel_Guitarra_0,
#  X_Daniel_Guitarra_1,
#  X_Daniel_Guitarra_10,
#  X_Daniel_Guitarra_11,
#  X_Daniel_Guitarra_12,
#  X_Daniel_Guitarra_2,
#  X_Daniel_Guitarra_3,
#  X_Daniel_Guitarra_4,
#  X_Daniel_Guitarra_5,
#  X_Daniel_Guitarra_6,
#  X_Daniel_Guitarra_7,
#  X_Daniel_Guitarra_8,
#  X_Daniel_Guitarra_9,
#  X_Daniel_Teclado_0,
#  X_Daniel_Teclado_1,
#  X_Daniel_Teclado_10,
#  X_Daniel_Teclado_11,
#  X_Daniel_Teclado_12,
#  X_Daniel_Teclado_2,
#  X_Daniel_Teclado_3,
#  X_Daniel_Teclado_4,
#  X_Daniel_Teclado_5,
#  X_Daniel_Teclado_6,
#  X_Daniel_Teclado_7,
#  X_Daniel_Teclado_8,
#  X_Daniel_Teclado_9,
#  X_Daniel_Violão_0,
#  X_Daniel_Violão_1,
#  X_Daniel_Violão_10,
#  X_Daniel_Violão_11,
#  X_Daniel_Violão_12,
#  X_Daniel_Violão_2,
#  X_Daniel_Violão_3,
#  X_Daniel_Violão_4,
#  X_Daniel_Violão_5,
#  X_Daniel_Violão_6,
#  X_Daniel_Violão_7,
#  X_Daniel_Violão_8,
#  X_Daniel_Violão_9,
#  X_Enzo_Baixo_0,
#  X_Enzo_Baixo_1,
#  X_Enzo_Baixo_10,
#  X_Enzo_Baixo_11,
#  X_Enzo_Baixo_12,
#  X_Enzo_Baixo_2,
#  X_Enzo_Baixo_3,
#  X_Enzo_Baixo_4,
#  X_Enzo_Baixo_5,
#  X_Enzo_Baixo_6,
#  X_Enzo_Baixo_7,
#  X_Enzo_Baixo_8,
#  X_Enzo_Baixo_9,
#  X_Enzo_Bateria_0,
#  X_Enzo_Bateria_1,
#  X_Enzo_Bateria_10,
#  X_Enzo_Bateria_11,
#  X_Enzo_Bateria_12,
#  X_Enzo_Bateria_2,
#  X_Enzo_Bateria_3,
#  X_Enzo_Bateria_4,
#  X_Enzo_Bateria_5,
#  X_Enzo_Bateria_6,
#  X_Enzo_Bateria_7,
#  X_Enzo_Bateria_8,
#  X_Enzo_Bateria_9,
#  X_Enzo_Guitarra_0,
#  X_Enzo_Guitarra_1,
#  X_Enzo_Guitarra_10,
#  X_Enzo_Guitarra_11,
#  X_Enzo_Guitarra_12,
#  X_Enzo_Guitarra_2,
#  X_Enzo_Guitarra_3,
#  X_Enzo_Guitarra_4,
#  X_Enzo_Guitarra_5,
#  X_Enzo_Guitarra_6,
#  X_Enzo_Guitarra_7,
#  X_Enzo_Guitarra_8,
#  X_Enzo_Guitarra_9,
#  X_Enzo_Teclado_0,
#  X_Enzo_Teclado_1,
#  X_Enzo_Teclado_10,
#  X_Enzo_Teclado_11,
#  X_Enzo_Teclado_12,
#  X_Enzo_Teclado_2,
#  X_Enzo_Teclado_3,
#  X_Enzo_Teclado_4,
#  X_Enzo_Teclado_5,
#  X_Enzo_Teclado_6,
#  X_Enzo_Teclado_7,
#  X_Enzo_Teclado_8,
#  X_Enzo_Teclado_9,
#  X_Enzo_Violão_0,
#  X_Enzo_Violão_1,
#  X_Enzo_Violão_10,
#  X_Enzo_Violão_11,
#  X_Enzo_Violão_12,
#  X_Enzo_Violão_2,
#  X_Enzo_Violão_3,
#  X_Enzo_Violão_4,
#  X_Enzo_Violão_5,
#  X_Enzo_Violão_6,
#  X_Enzo_Violão_7,
#  X_Enzo_Violão_8,
#  X_Enzo_Violão_9,
#  X_Everlyn_Baixo_0,
#  X_Everlyn_Baixo_1,
#  X_Everlyn_Baixo_10,
#  X_Everlyn_Baixo_11,
#  X_Everlyn_Baixo_12,
#  X_Everlyn_Baixo_2,
#  X_Everlyn_Baixo_3,
#  X_Everlyn_Baixo_4,
#  X_Everlyn_Baixo_5,
#  X_Everlyn_Baixo_6,
#  X_Everlyn_Baixo_7,
#  X_Everlyn_Baixo_8,
#  X_Everlyn_Baixo_9,
#  X_Everlyn_Bateria_0,
#  X_Everlyn_Bateria_1,
#  X_Everlyn_Bateria_10,
#  X_Everlyn_Bateria_11,
#  X_Everlyn_Bateria_12,
#  X_Everlyn_Bateria_2,
#  X_Everlyn_Bateria_3,
#  X_Everlyn_Bateria_4,
#  X_Everlyn_Bateria_5,
#  X_Everlyn_Bateria_6,
#  X_Everlyn_Bateria_7,
#  X_Everlyn_Bateria_8,
#  X_Everlyn_Bateria_9,
#  X_Everlyn_Guitarra_0,
#  X_Everlyn_Guitarra_1,
#  X_Everlyn_Guitarra_10,
#  X_Everlyn_Guitarra_11,
#  X_Everlyn_Guitarra_12,
#  X_Everlyn_Guitarra_2,
#  X_Everlyn_Guitarra_3,
#  X_Everlyn_Guitarra_4,
#  X_Everlyn_Guitarra_5,
#  X_Everlyn_Guitarra_6,
#  X_Everlyn_Guitarra_7,
#  X_Everlyn_Guitarra_8,
#  X_Everlyn_Guitarra_9,
#  X_Everlyn_Teclado_0,
#  X_Everlyn_Teclado_1,
#  X_Everlyn_Teclado_10,
#  X_Everlyn_Teclado_11,
#  X_Everlyn_Teclado_12,
#  X_Everlyn_Teclado_2,
#  X_Everlyn_Teclado_3,
#  X_Everlyn_Teclado_4,
#  X_Everlyn_Teclado_5,
#  X_Everlyn_Teclado_6,
#  X_Everlyn_Teclado_7,
#  X_Everlyn_Teclado_8,
#  X_Everlyn_Teclado_9,
#  X_Everlyn_Violão_0,
#  X_Everlyn_Violão_1,
#  X_Everlyn_Violão_10,
#  X_Everlyn_Violão_11,
#  X_Everlyn_Violão_12,
#  X_Everlyn_Violão_2,
#  X_Everlyn_Violão_3,
#  X_Everlyn_Violão_4,
#  X_Everlyn_Violão_5,
#  X_Everlyn_Violão_6,
#  X_Everlyn_Violão_7,
#  X_Everlyn_Violão_8,
#  X_Everlyn_Violão_9,
#  X_Gabriel_Baixo_0,
#  X_Gabriel_Baixo_1,
#  X_Gabriel_Baixo_10,
#  X_Gabriel_Baixo_11,
#  X_Gabriel_Baixo_12,
#  X_Gabriel_Baixo_2,
#  X_Gabriel_Baixo_3,
#  X_Gabriel_Baixo_4,
#  X_Gabriel_Baixo_5,
#  X_Gabriel_Baixo_6,
#  X_Gabriel_Baixo_7,
#  X_Gabriel_Baixo_8,
#  X_Gabriel_Baixo_9,
#  X_Gabriel_Bateria_0,
#  X_Gabriel_Bateria_1,
#  X_Gabriel_Bateria_10,
#  X_Gabriel_Bateria_11,
#  X_Gabriel_Bateria_12,
#  X_Gabriel_Bateria_2,
#  X_Gabriel_Bateria_3,
#  X_Gabriel_Bateria_4,
#  X_Gabriel_Bateria_5,
#  X_Gabriel_Bateria_6,
#  X_Gabriel_Bateria_7,
#  X_Gabriel_Bateria_8,
#  X_Gabriel_Bateria_9,
#  X_Gabriel_Guitarra_0,
#  X_Gabriel_Guitarra_1,
#  X_Gabriel_Guitarra_10,
#  X_Gabriel_Guitarra_11,
#  X_Gabriel_Guitarra_12,
#  X_Gabriel_Guitarra_2,
#  X_Gabriel_Guitarra_3,
#  X_Gabriel_Guitarra_4,
#  X_Gabriel_Guitarra_5,
#  X_Gabriel_Guitarra_6,
#  X_Gabriel_Guitarra_7,
#  X_Gabriel_Guitarra_8,
#  X_Gabriel_Guitarra_9,
#  X_Gabriel_Teclado_0,
#  X_Gabriel_Teclado_1,
#  X_Gabriel_Teclado_10,
#  X_Gabriel_Teclado_11,
#  X_Gabriel_Teclado_12,
#  X_Gabriel_Teclado_2,
#  X_Gabriel_Teclado_3,
#  X_Gabriel_Teclado_4,
#  X_Gabriel_Teclado_5,
#  X_Gabriel_Teclado_6,
#  X_Gabriel_Teclado_7,
#  X_Gabriel_Teclado_8,
#  X_Gabriel_Teclado_9,
#  X_Gabriel_Violão_0,
#  X_Gabriel_Violão_1,
#  X_Gabriel_Violão_10,
#  X_Gabriel_Violão_11,
#  X_Gabriel_Violão_12,
#  X_Gabriel_Violão_2,
#  X_Gabriel_Violão_3,
#  X_Gabriel_Violão_4,
#  X_Gabriel_Violão_5,
#  X_Gabriel_Violão_6,
#  X_Gabriel_Violão_7,
#  X_Gabriel_Violão_8,
#  X_Gabriel_Violão_9,
#  X_Henrique_Baixo_0,
#  X_Henrique_Baixo_1,
#  X_Henrique_Baixo_10,
#  X_Henrique_Baixo_11,
#  X_Henrique_Baixo_12,
#  X_Henrique_Baixo_2,
#  X_Henrique_Baixo_3,
#  X_Henrique_Baixo_4,
#  X_Henrique_Baixo_5,
#  X_Henrique_Baixo_6,
#  X_Henrique_Baixo_7,
#  X_Henrique_Baixo_8,
#  X_Henrique_Baixo_9,
#  X_Henrique_Bateria_0,
#  X_Henrique_Bateria_1,
#  X_Henrique_Bateria_10,
#  X_Henrique_Bateria_11,
#  X_Henrique_Bateria_12,
#  X_Henrique_Bateria_2,
#  X_Henrique_Bateria_3,
#  X_Henrique_Bateria_4,
#  X_Henrique_Bateria_5,
#  X_Henrique_Bateria_6,
#  X_Henrique_Bateria_7,
#  X_Henrique_Bateria_8,
#  X_Henrique_Bateria_9,
#  X_Henrique_Guitarra_0,
#  X_Henrique_Guitarra_1,
#  X_Henrique_Guitarra_10,
#  X_Henrique_Guitarra_11,
#  X_Henrique_Guitarra_12,
#  X_Henrique_Guitarra_2,
#  X_Henrique_Guitarra_3,
#  X_Henrique_Guitarra_4,
#  X_Henrique_Guitarra_5,
#  X_Henrique_Guitarra_6,
#  X_Henrique_Guitarra_7,
#  X_Henrique_Guitarra_8,
#  X_Henrique_Guitarra_9,
#  X_Henrique_Teclado_0,
#  X_Henrique_Teclado_1,
#  X_Henrique_Teclado_10,
#  X_Henrique_Teclado_11,
#  X_Henrique_Teclado_12,
#  X_Henrique_Teclado_2,
#  X_Henrique_Teclado_3,
#  X_Henrique_Teclado_4,
#  X_Henrique_Teclado_5,
#  X_Henrique_Teclado_6,
#  X_Henrique_Teclado_7,
#  X_Henrique_Teclado_8,
#  X_Henrique_Teclado_9,
#  X_Henrique_Violão_0,
#  X_Henrique_Violão_1,
#  X_Henrique_Violão_10,
#  X_Henrique_Violão_11,
#  X_Henrique_Violão_12,
#  X_Henrique_Violão_2,
#  X_Henrique_Violão_3,
#  X_Henrique_Violão_4,
#  X_Henrique_Violão_5,
#  X_Henrique_Violão_6,
#  X_Henrique_Violão_7,
#  X_Henrique_Violão_8,
#  X_Henrique_Violão_9,
#  X_Israel_Baixo_0,
#  X_Israel_Baixo_1,
#  X_Israel_Baixo_10,
#  X_Israel_Baixo_11,
#  X_Israel_Baixo_12,
#  X_Israel_Baixo_2,
#  X_Israel_Baixo_3,
#  X_Israel_Baixo_4,
#  X_Israel_Baixo_5,
#  X_Israel_Baixo_6,
#  X_Israel_Baixo_7,
#  X_Israel_Baixo_8,
#  X_Israel_Baixo_9,
#  X_Israel_Bateria_0,
#  X_Israel_Bateria_1,
#  X_Israel_Bateria_10,
#  X_Israel_Bateria_11,
#  X_Israel_Bateria_12,
#  X_Israel_Bateria_2,
#  X_Israel_Bateria_3,
#  X_Israel_Bateria_4,
#  X_Israel_Bateria_5,
#  X_Israel_Bateria_6,
#  X_Israel_Bateria_7,
#  X_Israel_Bateria_8,
#  X_Israel_Bateria_9,
#  X_Israel_Guitarra_0,
#  X_Israel_Guitarra_1,
#  X_Israel_Guitarra_10,
#  X_Israel_Guitarra_11,
#  X_Israel_Guitarra_12,
#  X_Israel_Guitarra_2,
#  X_Israel_Guitarra_3,
#  X_Israel_Guitarra_4,
#  X_Israel_Guitarra_5,
#  X_Israel_Guitarra_6,
#  X_Israel_Guitarra_7,
#  X_Israel_Guitarra_8,
#  X_Israel_Guitarra_9,
#  X_Israel_Teclado_0,
#  X_Israel_Teclado_1,
#  X_Israel_Teclado_10,
#  X_Israel_Teclado_11,
#  X_Israel_Teclado_12,
#  X_Israel_Teclado_2,
#  X_Israel_Teclado_3,
#  X_Israel_Teclado_4,
#  X_Israel_Teclado_5,
#  X_Israel_Teclado_6,
#  X_Israel_Teclado_7,
#  X_Israel_Teclado_8,
#  X_Israel_Teclado_9,
#  X_Israel_Violão_0,
#  X_Israel_Violão_1,
#  X_Israel_Violão_10,
#  X_Israel_Violão_11,
#  X_Israel_Violão_12,
#  X_Israel_Violão_2,
#  X_Israel_Violão_3,
#  X_Israel_Violão_4,
#  X_Israel_Violão_5,
#  X_Israel_Violão_6,
#  X_Israel_Violão_7,
#  X_Israel_Violão_8,
#  X_Israel_Violão_9,
#  X_Júlia_Baixo_0,
#  X_Júlia_Baixo_1,
#  X_Júlia_Baixo_10,
#  X_Júlia_Baixo_11,
#  X_Júlia_Baixo_12,
#  X_Júlia_Baixo_2,
#  X_Júlia_Baixo_3,
#  X_Júlia_Baixo_4,
#  X_Júlia_Baixo_5,
#  X_Júlia_Baixo_6,
#  X_Júlia_Baixo_7,
#  X_Júlia_Baixo_8,
#  X_Júlia_Baixo_9,
#  X_Júlia_Bateria_0,
#  X_Júlia_Bateria_1,
#  X_Júlia_Bateria_10,
#  X_Júlia_Bateria_11,
#  X_Júlia_Bateria_12,
#  X_Júlia_Bateria_2,
#  X_Júlia_Bateria_3,
#  X_Júlia_Bateria_4,
#  X_Júlia_Bateria_5,
#  X_Júlia_Bateria_6,
#  X_Júlia_Bateria_7,
#  X_Júlia_Bateria_8,
#  X_Júlia_Bateria_9,
#  X_Júlia_Guitarra_0,
#  X_Júlia_Guitarra_1,
#  X_Júlia_Guitarra_10,
#  X_Júlia_Guitarra_11,
#  X_Júlia_Guitarra_12,
#  X_Júlia_Guitarra_2,
#  X_Júlia_Guitarra_3,
#  X_Júlia_Guitarra_4,
#  X_Júlia_Guitarra_5,
#  X_Júlia_Guitarra_6,
#  X_Júlia_Guitarra_7,
#  X_Júlia_Guitarra_8,
#  X_Júlia_Guitarra_9,
#  X_Júlia_Teclado_0,
#  X_Júlia_Teclado_1,
#  X_Júlia_Teclado_10,
#  X_Júlia_Teclado_11,
#  X_Júlia_Teclado_12,
#  X_Júlia_Teclado_2,
#  X_Júlia_Teclado_3,
#  X_Júlia_Teclado_4,
#  X_Júlia_Teclado_5,
#  X_Júlia_Teclado_6,
#  X_Júlia_Teclado_7,
#  X_Júlia_Teclado_8,
#  X_Júlia_Teclado_9,
#  X_Júlia_Violão_0,
#  X_Júlia_Violão_1,
#  X_Júlia_Violão_10,
#  X_Júlia_Violão_11,
#  X_Júlia_Violão_12,
#  X_Júlia_Violão_2,
#  X_Júlia_Violão_3,
#  X_Júlia_Violão_4,
#  X_Júlia_Violão_5,
#  X_Júlia_Violão_6,
#  X_Júlia_Violão_7,
#  X_Júlia_Violão_8,
#  X_Júlia_Violão_9,
#  X_Lucas_Baixo_0,
#  X_Lucas_Baixo_1,
#  X_Lucas_Baixo_10,
#  X_Lucas_Baixo_11,
#  X_Lucas_Baixo_12,
#  X_Lucas_Baixo_2,
#  X_Lucas_Baixo_3,
#  X_Lucas_Baixo_4,
#  X_Lucas_Baixo_5,
#  X_Lucas_Baixo_6,
#  X_Lucas_Baixo_7,
#  X_Lucas_Baixo_8,
#  X_Lucas_Baixo_9,
#  X_Lucas_Bateria_0,
#  X_Lucas_Bateria_1,
#  X_Lucas_Bateria_10,
#  X_Lucas_Bateria_11,
#  X_Lucas_Bateria_12,
#  X_Lucas_Bateria_2,
#  X_Lucas_Bateria_3,
#  X_Lucas_Bateria_4,
#  X_Lucas_Bateria_5,
#  X_Lucas_Bateria_6,
#  X_Lucas_Bateria_7,
#  X_Lucas_Bateria_8,
#  X_Lucas_Bateria_9,
#  X_Lucas_Guitarra_0,
#  X_Lucas_Guitarra_1,
#  X_Lucas_Guitarra_10,
#  X_Lucas_Guitarra_11,
#  X_Lucas_Guitarra_12,
#  X_Lucas_Guitarra_2,
#  X_Lucas_Guitarra_3,
#  X_Lucas_Guitarra_4,
#  X_Lucas_Guitarra_5,
#  X_Lucas_Guitarra_6,
#  X_Lucas_Guitarra_7,
#  X_Lucas_Guitarra_8,
#  X_Lucas_Guitarra_9,
#  X_Lucas_Teclado_0,
#  X_Lucas_Teclado_1,
#  X_Lucas_Teclado_10,
#  X_Lucas_Teclado_11,
#  X_Lucas_Teclado_12,
#  X_Lucas_Teclado_2,
#  X_Lucas_Teclado_3,
#  X_Lucas_Teclado_4,
#  X_Lucas_Teclado_5,
#  X_Lucas_Teclado_6,
#  X_Lucas_Teclado_7,
#  X_Lucas_Teclado_8,
#  X_Lucas_Teclado_9,
#  X_Lucas_Violão_0,
#  X_Lucas_Violão_1,
#  X_Lucas_Violão_10,
#  X_Lucas_Violão_11,
#  X_Lucas_Violão_12,
#  X_Lucas_Violão_2,
#  X_Lucas_Violão_3,
#  X_Lucas_Violão_4,
#  X_Lucas_Violão_5,
#  X_Lucas_Violão_6,
#  X_Lucas_Violão_7,
#  X_Lucas_Violão_8,
#  X_Lucas_Violão_9,
#  X_Marcela_Baixo_0,
#  X_Marcela_Baixo_1,
#  X_Marcela_Baixo_10,
#  X_Marcela_Baixo_11,
#  X_Marcela_Baixo_12,
#  X_Marcela_Baixo_2,
#  X_Marcela_Baixo_3,
#  X_Marcela_Baixo_4,
#  X_Marcela_Baixo_5,
#  X_Marcela_Baixo_6,
#  X_Marcela_Baixo_7,
#  X_Marcela_Baixo_8,
#  X_Marcela_Baixo_9,
#  X_Marcela_Bateria_0,
#  X_Marcela_Bateria_1,
#  X_Marcela_Bateria_10,
#  X_Marcela_Bateria_11,
#  X_Marcela_Bateria_12,
#  X_Marcela_Bateria_2,
#  X_Marcela_Bateria_3,
#  X_Marcela_Bateria_4,
#  X_Marcela_Bateria_5,
#  X_Marcela_Bateria_6,
#  X_Marcela_Bateria_7,
#  X_Marcela_Bateria_8,
#  X_Marcela_Bateria_9,
#  X_Marcela_Guitarra_0,
#  X_Marcela_Guitarra_1,
#  X_Marcela_Guitarra_10,
#  X_Marcela_Guitarra_11,
#  X_Marcela_Guitarra_12,
#  X_Marcela_Guitarra_2,
#  X_Marcela_Guitarra_3,
#  X_Marcela_Guitarra_4,
#  X_Marcela_Guitarra_5,
#  X_Marcela_Guitarra_6,
#  X_Marcela_Guitarra_7,
#  X_Marcela_Guitarra_8,
#  X_Marcela_Guitarra_9,
#  X_Marcela_Teclado_0,
#  X_Marcela_Teclado_1,
#  X_Marcela_Teclado_10,
#  X_Marcela_Teclado_11,
#  X_Marcela_Teclado_12,
#  X_Marcela_Teclado_2,
#  X_Marcela_Teclado_3,
#  X_Marcela_Teclado_4,
#  X_Marcela_Teclado_5,
#  X_Marcela_Teclado_6,
#  X_Marcela_Teclado_7,
#  X_Marcela_Teclado_8,
#  X_Marcela_Teclado_9,
#  X_Marcela_Violão_0,
#  X_Marcela_Violão_1,
#  X_Marcela_Violão_10,
#  X_Marcela_Violão_11,
#  X_Marcela_Violão_12,
#  X_Marcela_Violão_2,
#  X_Marcela_Violão_3,
#  X_Marcela_Violão_4,
#  X_Marcela_Violão_5,
#  X_Marcela_Violão_6,
#  X_Marcela_Violão_7,
#  X_Marcela_Violão_8,
#  X_Marcela_Violão_9,
#  X_Mauri_Baixo_0,
#  X_Mauri_Baixo_1,
#  X_Mauri_Baixo_10,
#  X_Mauri_Baixo_11,
#  X_Mauri_Baixo_12,
#  X_Mauri_Baixo_2,
#  X_Mauri_Baixo_3,
#  X_Mauri_Baixo_4,
#  X_Mauri_Baixo_5,
#  X_Mauri_Baixo_6,
#  X_Mauri_Baixo_7,
#  X_Mauri_Baixo_8,
#  X_Mauri_Baixo_9,
#  X_Mauri_Bateria_0,
#  X_Mauri_Bateria_1,
#  X_Mauri_Bateria_10,
#  X_Mauri_Bateria_11,
#  X_Mauri_Bateria_12,
#  X_Mauri_Bateria_2,
#  X_Mauri_Bateria_3,
#  X_Mauri_Bateria_4,
#  X_Mauri_Bateria_5,
#  X_Mauri_Bateria_6,
#  X_Mauri_Bateria_7,
#  X_Mauri_Bateria_8,
#  X_Mauri_Bateria_9,
#  X_Mauri_Guitarra_0,
#  X_Mauri_Guitarra_1,
#  X_Mauri_Guitarra_10,
#  X_Mauri_Guitarra_11,
#  X_Mauri_Guitarra_12,
#  X_Mauri_Guitarra_2,
#  X_Mauri_Guitarra_3,
#  X_Mauri_Guitarra_4,
#  X_Mauri_Guitarra_5,
#  X_Mauri_Guitarra_6,
#  X_Mauri_Guitarra_7,
#  X_Mauri_Guitarra_8,
#  X_Mauri_Guitarra_9,
#  X_Mauri_Teclado_0,
#  X_Mauri_Teclado_1,
#  X_Mauri_Teclado_10,
#  X_Mauri_Teclado_11,
#  X_Mauri_Teclado_12,
#  X_Mauri_Teclado_2,
#  X_Mauri_Teclado_3,
#  X_Mauri_Teclado_4,
#  X_Mauri_Teclado_5,
#  X_Mauri_Teclado_6,
#  X_Mauri_Teclado_7,
#  X_Mauri_Teclado_8,
#  X_Mauri_Teclado_9,
#  X_Mauri_Violão_0,
#  X_Mauri_Violão_1,
#  X_Mauri_Violão_10,
#  X_Mauri_Violão_11,
#  X_Mauri_Violão_12,
#  X_Mauri_Violão_2,
#  X_Mauri_Violão_3,
#  X_Mauri_Violão_4,
#  X_Mauri_Violão_5,
#  X_Mauri_Violão_6,
#  X_Mauri_Violão_7,
#  X_Mauri_Violão_8,
#  X_Mauri_Violão_9,
#  X_Osvaldo_Baixo_0,
#  X_Osvaldo_Baixo_1,
#  X_Osvaldo_Baixo_10,
#  X_Osvaldo_Baixo_11,
#  X_Osvaldo_Baixo_12,
#  X_Osvaldo_Baixo_2,
#  X_Osvaldo_Baixo_3,
#  X_Osvaldo_Baixo_4,
#  X_Osvaldo_Baixo_5,
#  X_Osvaldo_Baixo_6,
#  X_Osvaldo_Baixo_7,
#  X_Osvaldo_Baixo_8,
#  X_Osvaldo_Baixo_9,
#  X_Osvaldo_Bateria_0,
#  X_Osvaldo_Bateria_1,
#  X_Osvaldo_Bateria_10,
#  X_Osvaldo_Bateria_11,
#  X_Osvaldo_Bateria_12,
#  X_Osvaldo_Bateria_2,
#  X_Osvaldo_Bateria_3,
#  X_Osvaldo_Bateria_4,
#  X_Osvaldo_Bateria_5,
#  X_Osvaldo_Bateria_6,
#  X_Osvaldo_Bateria_7,
#  X_Osvaldo_Bateria_8,
#  X_Osvaldo_Bateria_9,
#  X_Osvaldo_Guitarra_0,
#  X_Osvaldo_Guitarra_1,
#  X_Osvaldo_Guitarra_10,
#  X_Osvaldo_Guitarra_11,
#  X_Osvaldo_Guitarra_12,
#  X_Osvaldo_Guitarra_2,
#  X_Osvaldo_Guitarra_3,
#  X_Osvaldo_Guitarra_4,
#  X_Osvaldo_Guitarra_5,
#  X_Osvaldo_Guitarra_6,
#  X_Osvaldo_Guitarra_7,
#  X_Osvaldo_Guitarra_8,
#  X_Osvaldo_Guitarra_9,
#  X_Osvaldo_Teclado_0,
#  X_Osvaldo_Teclado_1,
#  X_Osvaldo_Teclado_10,
#  X_Osvaldo_Teclado_11,
#  X_Osvaldo_Teclado_12,
#  X_Osvaldo_Teclado_2,
#  X_Osvaldo_Teclado_3,
#  X_Osvaldo_Teclado_4,
#  X_Osvaldo_Teclado_5,
#  X_Osvaldo_Teclado_6,
#  X_Osvaldo_Teclado_7,
#  X_Osvaldo_Teclado_8,
#  X_Osvaldo_Teclado_9,
#  X_Osvaldo_Violão_0,
#  X_Osvaldo_Violão_1,
#  X_Osvaldo_Violão_10,
#  X_Osvaldo_Violão_11,
#  X_Osvaldo_Violão_12,
#  X_Osvaldo_Violão_2,
#  X_Osvaldo_Violão_3,
#  X_Osvaldo_Violão_4,
#  X_Osvaldo_Violão_5,
#  X_Osvaldo_Violão_6,
#  X_Osvaldo_Violão_7,
#  X_Osvaldo_Violão_8,
#  X_Osvaldo_Violão_9,
#  X_Rafael_Baixo_0,
#  X_Rafael_Baixo_1,
#  X_Rafael_Baixo_10,
#  X_Rafael_Baixo_11,
#  X_Rafael_Baixo_12,
#  X_Rafael_Baixo_2,
#  X_Rafael_Baixo_3,
#  X_Rafael_Baixo_4,
#  X_Rafael_Baixo_5,
#  X_Rafael_Baixo_6,
#  X_Rafael_Baixo_7,
#  X_Rafael_Baixo_8,
#  X_Rafael_Baixo_9,
#  X_Rafael_Bateria_0,
#  X_Rafael_Bateria_1,
#  X_Rafael_Bateria_10,
#  X_Rafael_Bateria_11,
#  X_Rafael_Bateria_12,
#  X_Rafael_Bateria_2,
#  X_Rafael_Bateria_3,
#  X_Rafael_Bateria_4,
#  X_Rafael_Bateria_5,
#  X_Rafael_Bateria_6,
#  X_Rafael_Bateria_7,
#  X_Rafael_Bateria_8,
#  X_Rafael_Bateria_9,
#  X_Rafael_Guitarra_0,
#  X_Rafael_Guitarra_1,
#  X_Rafael_Guitarra_10,
#  X_Rafael_Guitarra_11,
#  X_Rafael_Guitarra_12,
#  X_Rafael_Guitarra_2,
#  X_Rafael_Guitarra_3,
#  X_Rafael_Guitarra_4,
#  X_Rafael_Guitarra_5,
#  X_Rafael_Guitarra_6,
#  X_Rafael_Guitarra_7,
#  X_Rafael_Guitarra_8,
#  X_Rafael_Guitarra_9,
#  X_Rafael_Teclado_0,
#  X_Rafael_Teclado_1,
#  X_Rafael_Teclado_10,
#  X_Rafael_Teclado_11,
#  X_Rafael_Teclado_12,
#  X_Rafael_Teclado_2,
#  X_Rafael_Teclado_3,
#  X_Rafael_Teclado_4,
#  X_Rafael_Teclado_5,
#  X_Rafael_Teclado_6,
#  X_Rafael_Teclado_7,
#  X_Rafael_Teclado_8,
#  X_Rafael_Teclado_9,
#  X_Rafael_Violão_0,
#  X_Rafael_Violão_1,
#  X_Rafael_Violão_10,
#  X_Rafael_Violão_11,
#  X_Rafael_Violão_12,
#  X_Rafael_Violão_2,
#  X_Rafael_Violão_3,
#  X_Rafael_Violão_4,
#  X_Rafael_Violão_5,
#  X_Rafael_Violão_6,
#  X_Rafael_Violão_7,
#  X_Rafael_Violão_8,
#  X_Rafael_Violão_9,
#  X_Ricardo_Baixo_0,
#  X_Ricardo_Baixo_1,
#  X_Ricardo_Baixo_10,
#  X_Ricardo_Baixo_11,
#  X_Ricardo_Baixo_12,
#  X_Ricardo_Baixo_2,
#  X_Ricardo_Baixo_3,
#  X_Ricardo_Baixo_4,
#  X_Ricardo_Baixo_5,
#  X_Ricardo_Baixo_6,
#  X_Ricardo_Baixo_7,
#  X_Ricardo_Baixo_8,
#  X_Ricardo_Baixo_9,
#  X_Ricardo_Bateria_0,
#  X_Ricardo_Bateria_1,
#  X_Ricardo_Bateria_10,
#  X_Ricardo_Bateria_11,
#  X_Ricardo_Bateria_12,
#  X_Ricardo_Bateria_2,
#  X_Ricardo_Bateria_3,
#  X_Ricardo_Bateria_4,
#  X_Ricardo_Bateria_5,
#  X_Ricardo_Bateria_6,
#  X_Ricardo_Bateria_7,
#  X_Ricardo_Bateria_8,
#  ...]

# %%
# Cria o DataFrame result com os índices de V e as colunas de df
result = pd.DataFrame(0, index=df.index, columns=P.index)

# Iterando sobre as colunas
for j in df.columns:
    for i in df.index:
        for k in result.columns:
          if df.loc[i, j] == k:
                result.loc[i, k] = 1

# %%
import pandas as pd

file_name = 'Dados Louvor Shalom.xlsx'

sheets_dict = pd.read_excel(file_name, sheet_name=['Instrumento', 'Peso dos Instrumentos', 'Peso dos Dias','Disponibilidade', 'Dias por Mês', 'Vozes'])

# Acesse cada sheet pelo nome
#Dias por Mês
P = sheets_dict['Instrumento'].set_index('Pessoas')
L = sheets_dict['Peso dos Instrumentos'].set_index('Instrumentos').squeeze()
D = pd.Series(sheets_dict['Peso dos Dias']['Peso'])
Disp = sheets_dict['Disponibilidade']
DPM = sheets_dict['Dias por Mês'].set_index('Pessoas')
V = sheets_dict['Vozes'].set_index('Pessoas')

# %%
from pulp import *

days = 2

# Definir o problema
prob_v = LpProblem("Alocacao_de_Cantores", LpMaximize)

# Variáveis de decisão
X = LpVariable.dicts("X", (V.index, V.columns, D.index), cat='Binary')

# Função objetivo
prob_v += lpSum([X[i][j][k] * V.loc[i, j] * L[j] * D[k] for i in V.index for j in V.columns for k in D.index])

# Restrições
for j in V.columns:
    for k in D.index:
        prob_v += lpSum([X[i][j][k] for i in V.index]) <= 1

for i in V.index:
    for k in D.index:
        prob_v += lpSum([X[i][j][k] for j in V.columns]) <= 1

for i in V.index:
    for k in range(len(D.index) - 3):
        prob_v += lpSum([X[i][j][D.index[k]] + X[i][j][D.index[k+1]] + X[i][j][D.index[k+2]] + X[i][j][D.index[k+2]] for j in V.columns]) <= DPM['Quantidade'][i]

for i in V.index:
    for j in V.columns:
        for k in D.index:
            if V.loc[i, j] == 0:
                prob_v += X[i][j][k] == 0

# Resolver o problema
prob_v.solve()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/hmbarros/.local/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/290e46bc3004452bbc85b8705442ee82-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /tmp/290e46bc3004452bbc85b8705442ee82-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 978 COLUMNS
# At line 7819 RHS
# At line 8793 BOUNDS
# At line 9730 ENDATA
# Problem MODEL has 973 rows, 936 columns and 4539 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1365 - 0.00 seconds
# Cgl0002I 507 variables fixed
# Cgl0003I 0 fixed, 0 tightened bounds, 62 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 59 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 55 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 49 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 43 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 36 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 25 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 17 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 6 strengthened rows, 0 substitutions
# Cgl0004I processed model has 228 rows, 399 columns (399 integer (399 of which binary)) and 1925 elements
# Cutoff increment increased from 1e-05 to 4.9999
# Cbc0038I Initial state - 67 integers unsatisfied sum - 20.04
# Cbc0038I Pass   1: suminf.    3.25000 (9) obj. -1176.88 iterations 98
# Cbc0038I Solution found of -1175
# Cbc0038I Before mini branch and bound, 332 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 228 rows 399 columns, reduced to 100 rows 62 columns
# Cbc0038I Mini branch and bound improved solution from -1175 to -1345 (0.07 seconds)
# Cbc0038I Round again with cutoff of -1351.5
# Cbc0038I Pass   2: suminf.    9.54998 (33) obj. -1351.5 iterations 113
# Cbc0038I Pass   3: suminf.    8.59579 (37) obj. -1351.5 iterations 28
# Cbc0038I Pass   4: suminf.    7.65415 (33) obj. -1351.5 iterations 28
# Cbc0038I Pass   5: suminf.    7.42332 (37) obj. -1351.5 iterations 46
# Cbc0038I Pass   6: suminf.    7.35207 (33) obj. -1351.5 iterations 12
# Cbc0038I Pass   7: suminf.    4.04998 (11) obj. -1351.5 iterations 83
# Cbc0038I Pass   8: suminf.    4.04998 (11) obj. -1351.5 iterations 8
# Cbc0038I Pass   9: suminf.    4.04998 (11) obj. -1351.5 iterations 6
# Cbc0038I Pass  10: suminf.   13.28704 (40) obj. -1351.5 iterations 135
# Cbc0038I Pass  11: suminf.    1.93333 (7) obj. -1351.5 iterations 87
# Cbc0038I Pass  12: suminf.    1.29998 (3) obj. -1351.5 iterations 45
# Cbc0038I Pass  13: suminf.    1.08332 (5) obj. -1351.5 iterations 36
# Cbc0038I Pass  14: suminf.    2.18333 (7) obj. -1351.5 iterations 105
# Cbc0038I Pass  15: suminf.    1.30833 (7) obj. -1351.5 iterations 1
# Cbc0038I Pass  16: suminf.    1.26666 (6) obj. -1351.5 iterations 18
# Cbc0038I Pass  17: suminf.    1.70002 (4) obj. -1351.5 iterations 63
# Cbc0038I Pass  18: suminf.    1.48333 (3) obj. -1351.5 iterations 73
# Cbc0038I Pass  19: suminf.    1.08332 (5) obj. -1351.5 iterations 98
# Cbc0038I Pass  20: suminf.    2.09999 (6) obj. -1351.5 iterations 102
# Cbc0038I Pass  21: suminf.    1.26666 (6) obj. -1351.5 iterations 4
# Cbc0038I Pass  22: suminf.    1.26666 (6) obj. -1351.5 iterations 5
# Cbc0038I Pass  23: suminf.    1.70002 (4) obj. -1351.5 iterations 69
# Cbc0038I Pass  24: suminf.    1.50000 (3) obj. -1352.5 iterations 64
# Cbc0038I Pass  25: suminf.    1.29998 (3) obj. -1351.5 iterations 57
# Cbc0038I Pass  26: suminf.    1.08332 (5) obj. -1351.5 iterations 39
# Cbc0038I Pass  27: suminf.    2.09999 (6) obj. -1351.5 iterations 110
# Cbc0038I Pass  28: suminf.    1.26666 (6) obj. -1351.5 iterations 1
# Cbc0038I Pass  29: suminf.    1.26666 (6) obj. -1351.5 iterations 8
# Cbc0038I Pass  30: suminf.    1.70002 (4) obj. -1351.5 iterations 66
# Cbc0038I Pass  31: suminf.    1.50000 (3) obj. -1352.5 iterations 74
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 257 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 228 rows 399 columns, reduced to 149 rows 132 columns - 21 fixed gives 93, 75 - ok now
# Cbc0038I Full problem 228 rows 399 columns, reduced to 83 rows 70 columns
# Cbc0038I Mini branch and bound improved solution from -1345 to -1360 (0.13 seconds)
# Cbc0038I Round again with cutoff of -1365
# Cbc0038I Pass  31: suminf.   11.57810 (42) obj. -1365 iterations 36
# Cbc0038I Pass  32: suminf.   11.07803 (45) obj. -1365 iterations 80
# Cbc0038I Pass  33: suminf.   10.50778 (45) obj. -1365 iterations 8
# Cbc0038I Pass  34: suminf.   10.50776 (41) obj. -1365 iterations 3
# Cbc0038I Pass  35: suminf.    9.50777 (39) obj. -1365 iterations 16
# Cbc0038I Pass  36: suminf.    6.74996 (30) obj. -1365 iterations 68
# Cbc0038I Pass  37: suminf.    5.90622 (23) obj. -1365 iterations 14
# Cbc0038I Pass  38: suminf.    5.49996 (22) obj. -1365 iterations 8
# Cbc0038I Pass  39: suminf.    5.31246 (22) obj. -1365 iterations 4
# Cbc0038I Pass  40: suminf.    5.31246 (24) obj. -1365 iterations 9
# Cbc0038I Pass  41: suminf.    6.62498 (24) obj. -1365 iterations 81
# Cbc0038I Pass  42: suminf.    5.65619 (27) obj. -1365 iterations 54
# Cbc0038I Pass  43: suminf.    5.65619 (27) obj. -1365 iterations 10
# Cbc0038I Pass  44: suminf.    5.49998 (22) obj. -1365 iterations 67
# Cbc0038I Pass  45: suminf.    4.74996 (22) obj. -1365 iterations 69
# Cbc0038I Pass  46: suminf.    4.74996 (22) obj. -1365 iterations 12
# Cbc0038I Pass  47: suminf.    6.49996 (22) obj. -1365 iterations 59
# Cbc0038I Pass  48: suminf.    4.84368 (24) obj. -1365 iterations 45
# Cbc0038I Pass  49: suminf.    4.84368 (24) obj. -1365 iterations 13
# Cbc0038I Pass  50: suminf.    4.84368 (24) obj. -1365 iterations 11
# Cbc0038I Pass  51: suminf.    1.00002 (3) obj. -1365 iterations 168
# Cbc0038I Solution found of -1365
# Cbc0038I Before mini branch and bound, 259 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.16 seconds)
# Cbc0038I After 0.16 seconds - Feasibility pump exiting with objective of -1365 - took 0.09 seconds
# Cbc0012I Integer solution of -1365 found by feasibility pump after 0 iterations and 0 nodes (0.16 seconds)
# Cbc0001I Search completed - best objective -1365, took 0 iterations and 0 nodes (0.16 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -1365 to -1365
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1365.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.14
# Time (Wallclock seconds):       0.16
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.15   (Wallclock seconds):       0.17
# 1

# %%
# Imprimir o status da solução
print("Status:", LpStatus[prob_v.status])

# Imprimir o valor da função objetivo
print("Valor da função objetivo =", value(prob_v.objective))

# Dicionário para armazenar os resultados
resultados_v = {}

# Iterar sobre cada variável de decisão
for v in prob_v.variables():
    if v.varValue != 0:
        # Extrair o nome da pessoa, o voz e o dia
        _, pessoa, voz, dia = v.name.split("_", 3)

        # Se o dia ainda não está no dicionário, adicione-o
        if dia not in resultados_v:
            resultados_v[dia] = {}

        # Adicione a pessoa e o voz ao dia correspondente
        resultados_v[dia][voz] = pessoa

df_v = pd.DataFrame(columns=V.columns, index=sheets_dict['Peso dos Dias']['Dias']).fillna('')

print(prob_v.variables())
resultados_v

# Preencher o DataFrame com os resultados
# for dia in resultados:
#     for voz in resultados[dia]:
#         df_v.loc[sheets_dict['Peso dos Dias']['Dias'][int(dia)], voz] = resultados[dia][voz]


# if not pd.api.types.is_datetime64_any_dtype(df_v.index):
#     df_v.index = pd.to_datetime(df_v.index, origin='1899-12-30', unit='D')

# # Formatar o índice para o formato brasileiro
# df_v.index = df_v.index.strftime('%d/%m/%Y')

# df_v
# Out:
# Status: Optimal
# Valor da função objetivo = 1365.0
# [X_Ariane_Back_1_0, X_Ariane_Back_1_1, X_Ariane_Back_1_10, X_Ariane_Back_1_11, X_Ariane_Back_1_12, X_Ariane_Back_1_2, X_Ariane_Back_1_3, X_Ariane_Back_1_4, X_Ariane_Back_1_5, X_Ariane_Back_1_6, X_Ariane_Back_1_7, X_Ariane_Back_1_8, X_Ariane_Back_1_9, X_Ariane_Back_2_0, X_Ariane_Back_2_1, X_Ariane_Back_2_10, X_Ariane_Back_2_11, X_Ariane_Back_2_12, X_Ariane_Back_2_2, X_Ariane_Back_2_3, X_Ariane_Back_2_4, X_Ariane_Back_2_5, X_Ariane_Back_2_6, X_Ariane_Back_2_7, X_Ariane_Back_2_8, X_Ariane_Back_2_9, X_Ariane_Back_3_0, X_Ariane_Back_3_1, X_Ariane_Back_3_10, X_Ariane_Back_3_11, X_Ariane_Back_3_12, X_Ariane_Back_3_2, X_Ariane_Back_3_3, X_Ariane_Back_3_4, X_Ariane_Back_3_5, X_Ariane_Back_3_6, X_Ariane_Back_3_7, X_Ariane_Back_3_8, X_Ariane_Back_3_9, X_Ariane_Ministração_0, X_Ariane_Ministração_1, X_Ariane_Ministração_10, X_Ariane_Ministração_11, X_Ariane_Ministração_12, X_Ariane_Ministração_2, X_Ariane_Ministração_3, X_Ariane_Ministração_4, X_Ariane_Ministração_5, X_Ariane_Ministração_6, X_Ariane_Ministração_7, X_Ariane_Ministração_8, X_Ariane_Ministração_9, X_Bernardo_Back_1_0, X_Bernardo_Back_1_1, X_Bernardo_Back_1_10, X_Bernardo_Back_1_11, X_Bernardo_Back_1_12, X_Bernardo_Back_1_2, X_Bernardo_Back_1_3, X_Bernardo_Back_1_4, X_Bernardo_Back_1_5, X_Bernardo_Back_1_6, X_Bernardo_Back_1_7, X_Bernardo_Back_1_8, X_Bernardo_Back_1_9, X_Bernardo_Back_2_0, X_Bernardo_Back_2_1, X_Bernardo_Back_2_10, X_Bernardo_Back_2_11, X_Bernardo_Back_2_12, X_Bernardo_Back_2_2, X_Bernardo_Back_2_3, X_Bernardo_Back_2_4, X_Bernardo_Back_2_5, X_Bernardo_Back_2_6, X_Bernardo_Back_2_7, X_Bernardo_Back_2_8, X_Bernardo_Back_2_9, X_Bernardo_Back_3_0, X_Bernardo_Back_3_1, X_Bernardo_Back_3_10, X_Bernardo_Back_3_11, X_Bernardo_Back_3_12, X_Bernardo_Back_3_2, X_Bernardo_Back_3_3, X_Bernardo_Back_3_4, X_Bernardo_Back_3_5, X_Bernardo_Back_3_6, X_Bernardo_Back_3_7, X_Bernardo_Back_3_8, X_Bernardo_Back_3_9, X_Bernardo_Ministração_0, X_Bernardo_Ministração_1, X_Bernardo_Ministração_10, X_Bernardo_Ministração_11, X_Bernardo_Ministração_12, X_Bernardo_Ministração_2, X_Bernardo_Ministração_3, X_Bernardo_Ministração_4, X_Bernardo_Ministração_5, X_Bernardo_Ministração_6, X_Bernardo_Ministração_7, X_Bernardo_Ministração_8, X_Bernardo_Ministração_9, X_Dani_Voz_Back_1_0, X_Dani_Voz_Back_1_1, X_Dani_Voz_Back_1_10, X_Dani_Voz_Back_1_11, X_Dani_Voz_Back_1_12, X_Dani_Voz_Back_1_2, X_Dani_Voz_Back_1_3, X_Dani_Voz_Back_1_4, X_Dani_Voz_Back_1_5, X_Dani_Voz_Back_1_6, X_Dani_Voz_Back_1_7, X_Dani_Voz_Back_1_8, X_Dani_Voz_Back_1_9, X_Dani_Voz_Back_2_0, X_Dani_Voz_Back_2_1, X_Dani_Voz_Back_2_10, X_Dani_Voz_Back_2_11, X_Dani_Voz_Back_2_12, X_Dani_Voz_Back_2_2, X_Dani_Voz_Back_2_3, X_Dani_Voz_Back_2_4, X_Dani_Voz_Back_2_5, X_Dani_Voz_Back_2_6, X_Dani_Voz_Back_2_7, X_Dani_Voz_Back_2_8, X_Dani_Voz_Back_2_9, X_Dani_Voz_Back_3_0, X_Dani_Voz_Back_3_1, X_Dani_Voz_Back_3_10, X_Dani_Voz_Back_3_11, X_Dani_Voz_Back_3_12, X_Dani_Voz_Back_3_2, X_Dani_Voz_Back_3_3, X_Dani_Voz_Back_3_4, X_Dani_Voz_Back_3_5, X_Dani_Voz_Back_3_6, X_Dani_Voz_Back_3_7, X_Dani_Voz_Back_3_8, X_Dani_Voz_Back_3_9, X_Dani_Voz_Ministração_0, X_Dani_Voz_Ministração_1, X_Dani_Voz_Ministração_10, X_Dani_Voz_Ministração_11, X_Dani_Voz_Ministração_12, X_Dani_Voz_Ministração_2, X_Dani_Voz_Ministração_3, X_Dani_Voz_Ministração_4, X_Dani_Voz_Ministração_5, X_Dani_Voz_Ministração_6, X_Dani_Voz_Ministração_7, X_Dani_Voz_Ministração_8, X_Dani_Voz_Ministração_9, X_Daniel_Back_1_0, X_Daniel_Back_1_1, X_Daniel_Back_1_10, X_Daniel_Back_1_11, X_Daniel_Back_1_12, X_Daniel_Back_1_2, X_Daniel_Back_1_3, X_Daniel_Back_1_4, X_Daniel_Back_1_5, X_Daniel_Back_1_6, X_Daniel_Back_1_7, X_Daniel_Back_1_8, X_Daniel_Back_1_9, X_Daniel_Back_2_0, X_Daniel_Back_2_1, X_Daniel_Back_2_10, X_Daniel_Back_2_11, X_Daniel_Back_2_12, X_Daniel_Back_2_2, X_Daniel_Back_2_3, X_Daniel_Back_2_4, X_Daniel_Back_2_5, X_Daniel_Back_2_6, X_Daniel_Back_2_7, X_Daniel_Back_2_8, X_Daniel_Back_2_9, X_Daniel_Back_3_0, X_Daniel_Back_3_1, X_Daniel_Back_3_10, X_Daniel_Back_3_11, X_Daniel_Back_3_12 ...
# {'1_1': {'Back': 'Ariane'},
#  '1_10': {'Back': 'Ariane'},
#  '2_0': {'Back': 'Ariane'},
#  '2_4': {'Back': 'Ariane'},
#  '2_7': {'Back': 'Ariane'},
#  'Back_1_9': {'Voz': 'Dani'},
#  'Back_3_1': {'Voz': 'Dani'},
#  'Back_3_3': {'Voz': 'Dani'},
#  'Back_3_4': {'Voz': 'Dani'},
#  'Back_3_7': {'Voz': 'Dani'},
#  'Ministração_10': {'Voz': 'Dani'},
#  'Ministração_6': {'Voz': 'Dani'},
#  '1_5': {'Back': 'Everlyn'},
#  '2_11': {'Back': 'Everlyn'},
#  '3_10': {'Back': 'Everlyn'},
#  '3_12': {'Back': 'Everlyn'},
#  '3_2': {'Back': 'Everlyn'},
#  '3_8': {'Back': 'Everlyn'},
#  '1': {'Ministração': 'Everlyn'},
#  '4': {'Ministração': 'Everlyn'},
#  '7': {'Ministração': 'Everlyn'},
#  '1_6': {'Back': 'Henrique'},
#  '2_3': {'Back': 'Henrique'},
#  '2_9': {'Back': 'Henrique'},
#  '11': {'Ministração': 'Henrique'},
#  '2': {'Ministração': 'Henrique'},
#  '5': {'Ministração': 'Henrique'},
#  '8': {'Ministração': 'Henrique'},
#  '2_1': {'Back': 'Júlia'},
#  '2_12': {'Back': 'Júlia'},
#  '1_8': {'Back': 'Marcela'},
#  '2_2': {'Back': 'Marcela'},
#  '3_11': {'Back': 'Marcela'},
#  '3_5': {'Back': 'Marcela'},
#  '1_3': {'Back': 'Rafael'},
#  '2_6': {'Back': 'Rafael'},
#  '3_0': {'Back': 'Rafael'},
#  '3_9': {'Back': 'Rafael'},
#  '12': {'Ministração': 'Rafael'},
#  '1_0': {'Back': 'Ricardo'},
#  '1_11': {'Back': 'Ricardo'},
#  '1_2': {'Back': 'Ricardo'},
#  '1_4': {'Back': 'Ricardo'},
#  '1_7': {'Back': 'Ricardo'},
#  '2_10': {'Back': 'Ricardo'},
#  '2_5': {'Back': 'Ricardo'},
#  '2_8': {'Back': 'Ricardo'},
#  '1_12': {'Back': 'Tassi'},
#  '3_6': {'Back': 'Tassi'},
#  '0': {'Ministração': 'Tassi'},
#  '3': {'Ministração': 'Tassi'},
#  '9': {'Ministração': 'Tassi'}}
