# %% [markdown]
# # Problema de designação de pessoas **I** para instrumentos **J** e vozes **L** no dia **K**
# ---
#
# ##  i - Conjunto de pessoas
# ##  J - Conjunto de instrumentos
# ##  k - Conjunto de dias
# ##  l - Conjunto de vozes
#
# ---
#
# * Mij = Matriz Binária - Pessoa I toca Instrumento J
#
# * Sil = Matriz Binária - Pessoa I toca canta na posição L
#
# * PMj = Peso de cada instrumento J
# * PSl = Peso de cada voz L
#
# * Dk = Peso de cada dia K
#
# ### Solução
# * Xijk - Matriz Binária no R3
# * Yilk - Matriz Binária no R3
# * Zik -  Matriz binária no R2
#
# * **Se Xijk = 1 => A pessoa "i" tocará o instrumento 'j' no dia 'k'**
#
# * Se Yijl = 1 => A pessoa "i" cantará na posição 'l' no dia 'k'
#
# * **Se Xijk = 0 => A pessoa "i" não tocará o instrumento 'j' no dia 'k'**
#
# * Se Yijl = 0 => A pessoa "i" não cantará na posição 'l' no dia 'k'
#
# * **Somatório em i de Xijk <= 1 -  Um instrumento 'j' só pode ser tocado por uma pessoa 'i' em um dia 'k'**
#
# * Somatório em i de Yilk <= 1 - Uma voz 'l' só pode ser cantada por uma pessoa 'i' em um dia 'k'
#
# * **Somatório em 'j' de Xijk <= 1 - A pessoa "i" tocará somente um instrumento instrumento 'j' no dia 'k'**
#
# * Somatório em 'l' de Yilk <= 1 - A pessoa "i" cantará somente em uma posição "l" no dia "k"
#
# * **Zik - Pessoa i participa no dia k**
# * **Zik = 0 se Xijk e yilk = 0**
# * **Zik = 1 se Xijk ou yilk = 1**
#
#
# * **Zik + Zi(k+1) + Zi(k+2) + Zi(k+4) <= 2 para todo i - A pessoa "i" não participará mais do que dois dias seguidos.**
#
#
# * **Xijk = 0 se PMij = 0**
# * Yilk = 0 se PSil = 0
#
#
# * Maximize Xijk * Mij * PMj * Dk + Yilk * Sil * PSl * Dk

# %%
import pandas as pd

file_name = 'Dados Louvor Shalom.xlsx'

sheets_dict = pd.read_excel(file_name, sheet_name=['Instrumento', 'Peso dos Instrumentos', 'Peso dos Dias','Disponibilidade', 'Dias por Mês', 'Vozes', 'Peso das Vozes'])

# Acesse cada sheet pelo nome
#Dias por Mês
P = sheets_dict['Instrumento'].set_index('Pessoas')
P['nada'] = 1
V = sheets_dict['Vozes'].set_index('Pessoas')
V['nenhuma'] = 1

L = sheets_dict['Peso dos Instrumentos'].set_index('Instrumentos').squeeze()
L.loc['nada'] = 1
LV = sheets_dict['Peso das Vozes'].set_index('Voz').squeeze()
LV.loc['nenhuma'] = 1

D = sheets_dict['Peso dos Dias'].set_index('Dias')

Disp = sheets_dict['Disponibilidade'].set_index('Dias')
DPM = sheets_dict['Dias por Mês'].set_index('Pessoas')

# Convertendo os índices para o tipo datetime
D.index = pd.to_datetime(D.index)
Disp.index = pd.to_datetime(Disp.index)

# Formatando os índices para o formato desejado
D.index = D.index.strftime('%d_%m_%Y')
Disp.index = Disp.index.strftime('%d_%m_%Y')

controle_instrumento = pd.DataFrame(1, index=P.columns, columns=P.index)
controle_instrumento.loc['nada'] = 0

controle_voz = pd.DataFrame(1, index=V.columns, columns=V.index)
controle_voz.loc['nenhuma'] = 0

controle_instrumento
# Out:
# Pessoas      Ariane  Bernardo  Dani  Daniel  Enzo  Everlyn  Gabriel  Henrique  \
# Bateria           1         1     1       1     1        1        1         1
# Baixo             1         1     1       1     1        1        1         1
# Teclado           1         1     1       1     1        1        1         1
# Violão            1         1     1       1     1        1        1         1
# Guitarra          1         1     1       1     1        1        1         1
# Ministração       1         1     1       1     1        1        1         1
# Voz1              1         1     1       1     1        1        1         1
# Voz2              1         1     1       1     1        1        1         1
# Voz3              1         1     1       1     1        1        1         1
# nada              0         0     0       0     0        0        0         0
#
# Pessoas      Israel  Júlia  Lucas  Marcela  Mauri  Osvaldo  Rafael  Ricardo  \
# Bateria           1      1      1        1      1        1       1        1
# Baixo             1      1      1        1      1        1       1        1
# Teclado           1      1      1        1      1        1       1        1
# Violão            1      1      1        1      1        1       1        1
# Guitarra          1      1      1        1      1        1       1        1
# Ministração       1      1      1        1      1        1       1        1
# Voz1              1      1      1        1      1        1       1        1
# Voz2              1      1      1        1      1        1       1        1
# Voz3              1      1      1        1      1        1       1        1
# nada              0      0      0        0      0        0       0        0
#
# Pessoas      Tassi  Vinicius  Mikael
# Bateria          1         1       1
# Baixo            1         1       1
# Teclado          1         1       1
# Violão           1         1       1
# Guitarra         1         1       1
# Ministração      1         1       1
# Voz1             1         1       1
# Voz2             1         1       1
# Voz3             1         1       1
# nada             0         0       0

# %%
controle_voz
# Out:
# Pessoas      Ariane  Bernardo  Dani  Daniel  Enzo  Everlyn  Gabriel  Henrique  \
# Ministração       1         1     1       1     1        1        1         1
# Voz1              1         1     1       1     1        1        1         1
# Voz2              1         1     1       1     1        1        1         1
# Voz3              1         1     1       1     1        1        1         1
# nenhuma           0         0     0       0     0        0        0         0
#
# Pessoas      Israel  Júlia  Lucas  Marcela  Mauri  Osvaldo  Rafael  Ricardo  \
# Ministração       1      1      1        1      1        1       1        1
# Voz1              1      1      1        1      1        1       1        1
# Voz2              1      1      1        1      1        1       1        1
# Voz3              1      1      1        1      1        1       1        1
# nenhuma           0      0      0        0      0        0       0        0
#
# Pessoas      Tassi  Vinicius  Mikael
# Ministração      1         1       1
# Voz1             1         1       1
# Voz2             1         1       1
# Voz3             1         1       1
# nenhuma          0         0       0

# %%
import pandas as pd
from pulp import LpVariable, LpProblem, lpSum, LpMaximize, value

# Definindo a variável X como uma variável de 4 dimensões (i, j, k, l)
X = LpVariable.dicts("X", (P.index, P.columns, D.index, V.columns), cat='Binary')

# Criando o problema de otimização
prob = LpProblem("Problem", LpMaximize)

# Função objetivo atualizada
prob += lpSum([
    X[i][j][k][l] * Disp[i][k] * P.loc[i, j] * L[j] * D['Peso'][k] * V.loc[i, l] * LV[l]
    for i in P.index
    for j in P.columns
    for k in D.index
    for l in V.columns
])

# Um instrumento só é tocado por uma pessoa em cada dia K
for j in P.columns:  # para todo instrumento
    for k in D.index:  # para todo dia
        prob += lpSum([X[i][j][k][l] for i in P.index for l in V.columns]) <= 1

# Cada pessoa toca somente um instrumento cada dia
for i in P.index:  # cada pessoa
    for k in D.index:  # para todo dia
        prob += lpSum([X[i][j][k][l] for j in P.columns for l in V.columns]) <= 1

# Cada pessoa toca somente o número de dias que se ofereceu por mês
for i in P.index: 
    for k in range(len(D.index) - 3):
        prob += lpSum([
            X[i][j][D.index[k]][l] + X[i][j][D.index[k+1]][l] + X[i][j][D.index[k+2]][l] + X[i][j][D.index[k+3]][l]
            for j in P.columns for l in V.columns
        ]) <= DPM['Quantidade'][i]

# A pessoa não será alocada se não tocar o instrumento específico
for i in P.index:  # pessoas
    for j in P.columns:  # instrumentos
        for k in D.index:  # dias
            for l in V.columns:  # vozes
                if P.loc[i, j] == 0:  # tabela de capacidades. Pessoa i toca o instrumento j.
                    prob += X[i][j][k][l] == 0

# Cada pessoa canta somente uma voz por dia
for i in P.index:  # para cada pessoa
    for k in D.index:  # para cada dia
        prob += lpSum([X[i][j][k][l] for j in P.columns for l in V.columns]) <= 1

# Cada voz é cantada por apenas uma pessoa por dia
for l in V.columns:  # para cada voz
    for k in D.index:  # para cada dia
        prob += lpSum([X[i][j][k][l] for i in P.index for j in P.columns]) <= 1

# Resolver o problema
prob.solve()

# Tabela de vozes por dia
vozes_por_dia = pd.DataFrame(index=D.index, columns=V.columns)

for k in D.index:
    for l in V.columns:
        for i in P.index:
            for j in P.columns:
                if value(X[i][j][k][l]) == 1:
                    vozes_por_dia.at[k, l] = i

# Tabela de instrumentos por dia
instrumentos_por_dia = pd.DataFrame(index=D.index, columns=P.columns)

for k in D.index:
    for j in P.columns:
        for i in P.index:
            for l in V.columns:
                if value(X[i][j][k][l]) == 1:
                    instrumentos_por_dia.at[k, j] = i
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/hmbarros/.local/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/965cf2123c234f7196c8108e5de88d29-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /tmp/965cf2123c234f7196c8108e5de88d29-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 6786 COLUMNS
# At line 95481 RHS
# At line 102263 BOUNDS
# At line 111156 ENDATA
# Problem MODEL has 6781 rows, 8892 columns and 68856 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 6750 - 0.01 seconds
# Cgl0002I 5928 variables fixed
# Cgl0003I 0 fixed, 0 tightened bounds, 111 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 110 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 110 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 110 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 104 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 102 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 102 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 101 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 95 strengthened rows, 0 substitutions
# Cgl0004I processed model has 363 rows, 2054 columns (2054 integer (2054 of which binary)) and 13427 elements
# Cutoff increment increased from 1e-05 to 4.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -6750
# Cbc0038I Before mini branch and bound, 2054 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.43 seconds)
# Cbc0038I After 0.43 seconds - Feasibility pump exiting with objective of -6750 - took 0.00 seconds
# Cbc0012I Integer solution of -6750 found by feasibility pump after 0 iterations and 0 nodes (0.43 seconds)
# Cbc0001I Search completed - best objective -6750, took 0 iterations and 0 nodes (0.43 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -6750 to -6750
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                6750.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.46
# Time (Wallclock seconds):       0.46
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.50   (Wallclock seconds):       0.50
#
# Vozes por Dia:
#            Ministração    Voz1      Voz2      Voz3
# Dias
# 08_06_2024      Rafael   Júlia      Dani  Henrique
# 15_06_2024       Tassi     NaN   Marcela       NaN
# 22_06_2024     Everlyn     NaN       NaN    Ariane
# 29_06_2024     Ricardo     NaN       NaN       NaN
# 06_07_2024      Rafael    Dani  Henrique     Júlia
# 13_07_2024       Tassi     NaN       NaN   Marcela
# 20_07_2024     Everlyn     NaN       NaN    Ariane
# 27_07_2024     Ricardo     NaN       NaN       NaN
# 03_08_2024    Henrique   Júlia    Rafael      Dani
# 10_08_2024       Tassi     NaN       NaN       NaN
# 17_08_2024     Everlyn     NaN       NaN       NaN
# 24_08_2024     Ricardo     NaN    Ariane   Marcela
# 31_08_2024        Dani  Rafael  Henrique     Júlia
#
# Instrumentos por Dia:
#             Bateria Baixo   Teclado  Violão Guitarra Ministração     Voz1  \
# Dias
# 08_06_2024      NaN   NaN  Henrique  Rafael      NaN        Dani    Júlia
# 15_06_2024      NaN   NaN       NaN     NaN      NaN       Tassi  Marcela
# 22_06_2024      NaN   NaN       NaN     NaN      NaN     Everlyn      NaN
# 29_06_2024      NaN   NaN       NaN     NaN      NaN     Ricardo      NaN
# 06_07_2024      NaN   NaN  Henrique  Rafael      NaN        Dani      NaN
# 13_07_2024  Marcela   NaN       NaN     NaN      NaN       Tassi      NaN
# 20_07_2024      NaN   NaN       NaN     NaN      NaN     Everlyn   Ariane
# 27_07_2024      NaN   NaN       NaN     NaN      NaN     Ricardo      NaN
# 03_08_2024      NaN   NaN  Henrique  Rafael      NaN        Dani    Júlia
# 10_08_2024      NaN   NaN       NaN     NaN      NaN       Tassi      NaN
# 17_08_2024      NaN   NaN       NaN     NaN      NaN     Everlyn      NaN
# 24_08_2024      NaN   NaN       NaN     NaN      NaN     Ricardo   Ariane
# 31_08_2024      NaN   NaN  Henrique  Rafael      NaN        Dani      NaN
#
#                Voz2   Voz3
# Dias
# 08_06_2024      NaN    NaN
# 15_06_2024      NaN    NaN
# 22_06_2024   Ariane    NaN
# 29_06_2024      NaN    NaN
# 06_07_2024      NaN  Júlia
# 13_07_2024      NaN    NaN
# 20_07_2024      NaN    NaN
# 27_07_2024      NaN    NaN
# 03_08_2024      NaN    NaN
# 10_08_2024      NaN    NaN
# 17_08_2024      NaN    NaN
# 24_08_2024  Marcela    NaN
# 31_08_2024      NaN  Júlia

# %%
vozes_por_dia.fillna('', inplace=True)
vozes_por_dia
# Out:
#            Ministração    Voz1      Voz2      Voz3
# Dias
# 08_06_2024      Rafael   Júlia      Dani  Henrique
# 15_06_2024       Tassi           Marcela
# 22_06_2024     Everlyn                      Ariane
# 29_06_2024     Ricardo
# 06_07_2024      Rafael    Dani  Henrique     Júlia
# 13_07_2024       Tassi                     Marcela
# 20_07_2024     Everlyn                      Ariane
# 27_07_2024     Ricardo
# 03_08_2024    Henrique   Júlia    Rafael      Dani
# 10_08_2024       Tassi
# 17_08_2024     Everlyn
# 24_08_2024     Ricardo            Ariane   Marcela
# 31_08_2024        Dani  Rafael  Henrique     Júlia

# %%
instrumentos_por_dia.fillna('', inplace=True)
instrumentos_por_dia
# Out:
#             Bateria Baixo   Teclado  Violão Guitarra Ministração     Voz1  \
# Dias
# 08_06_2024                 Henrique  Rafael                 Dani    Júlia
# 15_06_2024                                                 Tassi  Marcela
# 22_06_2024                                               Everlyn
# 29_06_2024                                               Ricardo
# 06_07_2024                 Henrique  Rafael                 Dani
# 13_07_2024  Marcela                                        Tassi
# 20_07_2024                                               Everlyn   Ariane
# 27_07_2024                                               Ricardo
# 03_08_2024                 Henrique  Rafael                 Dani    Júlia
# 10_08_2024                                                 Tassi
# 17_08_2024                                               Everlyn
# 24_08_2024                                               Ricardo   Ariane
# 31_08_2024                 Henrique  Rafael                 Dani
#
#                Voz2   Voz3
# Dias
# 08_06_2024
# 15_06_2024
# 22_06_2024   Ariane
# 29_06_2024
# 06_07_2024           Júlia
# 13_07_2024
# 20_07_2024
# 27_07_2024
# 03_08_2024
# 10_08_2024
# 17_08_2024
# 24_08_2024  Marcela
# 31_08_2024           Júlia

# %%
import pandas as pd
from pulp import LpVariable, LpProblem, lpSum, LpMaximize, value

# Definindo a variável X como uma variável de 4 dimensões (i, j, k, l)
X = LpVariable.dicts("X", (P.index, P.columns, D.index, V.columns), cat='Binary')

# Criando o problema de otimização
prob = LpProblem("Problem", LpMaximize)

# Função objetivo atualizada
prob += lpSum([
    X[i][j][k][l] * Disp[i][k] * P.loc[i, j] * L[j] * D['Peso'][k] * V.loc[i, l] * LV[l]
    for i in P.index
    for j in P.columns
    for k in D.index
    for l in V.columns
])

# Restrições

# Um instrumento só é tocado por uma pessoa em cada dia K
for j in P.columns:  # para todo instrumento
    for k in D.index:  # para todo dia
        prob += lpSum([X[i][j][k][l] for i in P.index for l in V.columns]) <= 1

# Cada pessoa toca somente um instrumento cada dia
for i in P.index:  # cada pessoa
    for k in D.index:  # para todo dia
        prob += lpSum([X[i][j][k][l] for j in P.columns for l in V.columns]) <= 1

# Cada pessoa toca somente o número de dias que se ofereceu por mês
for i in P.index: 
    for k in range(len(D.index) - 3):
        prob += lpSum([
            X[i][j][D.index[k]][l] + X[i][j][D.index[k+1]][l] + X[i][j][D.index[k+2]][l] + X[i][j][D.index[k+3]][l]
            for j in P.columns for l in V.columns
        ]) <= DPM['Quantidade'][i]

# A pessoa não será alocada se não tocar o instrumento específico
for i in P.index:  # pessoas
    for j in P.columns:  # instrumentos
        for k in D.index:  # dias
            for l in V.columns:  # vozes
                if P.loc[i, j] == 0:  # tabela de capacidades. Pessoa i toca o instrumento j.
                    prob += X[i][j][k][l] == 0

# Cada pessoa canta somente uma voz por dia
for i in P.index:  # para cada pessoa
    for k in D.index:  # para cada dia
        prob += lpSum([X[i][j][k][l] for j in P.columns for l in V.columns]) <= 1

# Cada voz é cantada por apenas uma pessoa por dia
for l in V.columns:  # para cada voz
    for k in D.index:  # para cada dia
        prob += lpSum([X[i][j][k][l] for i in P.index for j in P.columns]) <= 1

# Resolver o problema
prob.solve()

# Tabela de vozes por dia
vozes_por_dia = pd.DataFrame(index=D.index, columns=V.columns)

for k in D.index:
    for l in V.columns:
        for i in P.index:
            for j in P.columns:
                if value(X[i][j][k][l]) == 1:
                    vozes_por_dia.at[k, l] = i

# Tabela de instrumentos por dia
instrumentos_por_dia = pd.DataFrame(index=D.index, columns=P.columns)

for k in D.index:
    for j in P.columns:
        for i in P.index:
            for l in V.columns:
                if value(X[i][j][k][l]) == 1:
                    instrumentos_por_dia.at[k, j] = i

print("Vozes por Dia:")
print(vozes_por_dia)
print("\nInstrumentos por Dia:")
print(instrumentos_por_dia)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/hmbarros/.local/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/e5e4abdab5e84a9ab0ae558709421f43-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /tmp/e5e4abdab5e84a9ab0ae558709421f43-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 8268 COLUMNS
# At line 116400 RHS
# At line 124664 BOUNDS
# At line 135780 ENDATA
# Problem MODEL has 8263 rows, 11115 columns and 83847 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 6750 - 0.02 seconds
# Cgl0002I 7410 variables fixed
# Cgl0003I 0 fixed, 0 tightened bounds, 110 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 110 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 110 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 110 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 103 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 101 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 101 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 101 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 95 strengthened rows, 0 substitutions
# Cgl0004I processed model has 363 rows, 2054 columns (2054 integer (2054 of which binary)) and 13423 elements
# Cutoff increment increased from 1e-05 to 4.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -6750
# Cbc0038I Before mini branch and bound, 2054 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.44 seconds)
# Cbc0038I After 0.44 seconds - Feasibility pump exiting with objective of -6750 - took 0.00 seconds
# Cbc0012I Integer solution of -6750 found by feasibility pump after 0 iterations and 0 nodes (0.44 seconds)
# Cbc0001I Search completed - best objective -6750, took 0 iterations and 0 nodes (0.45 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -6750 to -6750
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                6750.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.45
# Time (Wallclock seconds):       0.47
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.50   (Wallclock seconds):       0.52
#
# Vozes por Dia:
#            Ministração    Voz1      Voz2      Voz3 l_null
# Dias
# 08_06_2024      Rafael   Júlia      Dani  Henrique    NaN
# 15_06_2024       Tassi     NaN   Marcela       NaN    NaN
# 22_06_2024     Everlyn     NaN       NaN    Ariane    NaN
# 29_06_2024     Ricardo     NaN       NaN       NaN    NaN
# 06_07_2024      Rafael    Dani  Henrique     Júlia    NaN
# 13_07_2024       Tassi     NaN       NaN   Marcela    NaN
# 20_07_2024     Everlyn     NaN       NaN    Ariane    NaN
# 27_07_2024     Ricardo     NaN       NaN       NaN    NaN
# 03_08_2024    Henrique   Júlia    Rafael      Dani    NaN
# 10_08_2024       Tassi     NaN       NaN       NaN    NaN
# 17_08_2024     Everlyn     NaN       NaN       NaN    NaN
# 24_08_2024     Ricardo     NaN    Ariane   Marcela    NaN
# 31_08_2024        Dani  Rafael  Henrique     Júlia    NaN
#
# Instrumentos por Dia:
#             Bateria Baixo   Teclado  Violão Guitarra Ministração     Voz1  \
# Dias
# 08_06_2024      NaN   NaN  Henrique  Rafael      NaN        Dani    Júlia
# 15_06_2024      NaN   NaN       NaN     NaN      NaN       Tassi  Marcela
# 22_06_2024      NaN   NaN       NaN     NaN      NaN     Everlyn      NaN
# 29_06_2024      NaN   NaN       NaN     NaN      NaN     Ricardo      NaN
# 06_07_2024      NaN   NaN  Henrique  Rafael      NaN        Dani      NaN
# 13_07_2024  Marcela   NaN       NaN     NaN      NaN       Tassi      NaN
# 20_07_2024      NaN   NaN       NaN     NaN      NaN     Everlyn   Ariane
# 27_07_2024      NaN   NaN       NaN     NaN      NaN     Ricardo      NaN
# 03_08_2024      NaN   NaN  Henrique  Rafael      NaN        Dani    Júlia
# 10_08_2024      NaN   NaN       NaN     NaN      NaN       Tassi      NaN
# 17_08_2024      NaN   NaN       NaN     NaN      NaN     Everlyn      NaN
# 24_08_2024      NaN   NaN       NaN     NaN      NaN     Ricardo   Ariane
# 31_08_2024      NaN   NaN  Henrique  Rafael      NaN        Dani      NaN
#
#                Voz2   Voz3
# Dias
# 08_06_2024      NaN    NaN
# 15_06_2024      NaN    NaN
# 22_06_2024   Ariane    NaN
# 29_06_2024      NaN    NaN
# 06_07_2024      NaN  Júlia
# 13_07_2024      NaN    NaN
# 20_07_2024      NaN    NaN
# 27_07_2024      NaN    NaN
# 03_08_2024      NaN    NaN
# 10_08_2024      NaN    NaN
# 17_08_2024      NaN    NaN
# 24_08_2024  Marcela    NaN
# 31_08_2024      NaN  Júlia

# %%
vozes_por_dia
# Out:
#            Ministração    Voz1      Voz2      Voz3 l_null
# Dias
# 08_06_2024      Rafael   Júlia      Dani  Henrique    NaN
# 15_06_2024       Tassi     NaN   Marcela       NaN    NaN
# 22_06_2024     Everlyn     NaN       NaN    Ariane    NaN
# 29_06_2024     Ricardo     NaN       NaN       NaN    NaN
# 06_07_2024      Rafael    Dani  Henrique     Júlia    NaN
# 13_07_2024       Tassi     NaN       NaN   Marcela    NaN
# 20_07_2024     Everlyn     NaN       NaN    Ariane    NaN
# 27_07_2024     Ricardo     NaN       NaN       NaN    NaN
# 03_08_2024    Henrique   Júlia    Rafael      Dani    NaN
# 10_08_2024       Tassi     NaN       NaN       NaN    NaN
# 17_08_2024     Everlyn     NaN       NaN       NaN    NaN
# 24_08_2024     Ricardo     NaN    Ariane   Marcela    NaN
# 31_08_2024        Dani  Rafael  Henrique     Júlia    NaN

# %%
instrumentos_por_dia
# Out:
#             Bateria Baixo   Teclado  Violão Guitarra Ministração     Voz1  \
# Dias
# 08_06_2024      NaN   NaN  Henrique  Rafael      NaN        Dani    Júlia
# 15_06_2024      NaN   NaN       NaN     NaN      NaN       Tassi  Marcela
# 22_06_2024      NaN   NaN       NaN     NaN      NaN     Everlyn      NaN
# 29_06_2024      NaN   NaN       NaN     NaN      NaN     Ricardo      NaN
# 06_07_2024      NaN   NaN  Henrique  Rafael      NaN        Dani      NaN
# 13_07_2024  Marcela   NaN       NaN     NaN      NaN       Tassi      NaN
# 20_07_2024      NaN   NaN       NaN     NaN      NaN     Everlyn   Ariane
# 27_07_2024      NaN   NaN       NaN     NaN      NaN     Ricardo      NaN
# 03_08_2024      NaN   NaN  Henrique  Rafael      NaN        Dani    Júlia
# 10_08_2024      NaN   NaN       NaN     NaN      NaN       Tassi      NaN
# 17_08_2024      NaN   NaN       NaN     NaN      NaN     Everlyn      NaN
# 24_08_2024      NaN   NaN       NaN     NaN      NaN     Ricardo   Ariane
# 31_08_2024      NaN   NaN  Henrique  Rafael      NaN        Dani      NaN
#
#                Voz2   Voz3
# Dias
# 08_06_2024      NaN    NaN
# 15_06_2024      NaN    NaN
# 22_06_2024   Ariane    NaN
# 29_06_2024      NaN    NaN
# 06_07_2024      NaN  Júlia
# 13_07_2024      NaN    NaN
# 20_07_2024      NaN    NaN
# 27_07_2024      NaN    NaN
# 03_08_2024      NaN    NaN
# 10_08_2024      NaN    NaN
# 17_08_2024      NaN    NaN
# 24_08_2024  Marcela    NaN
# 31_08_2024      NaN  Júlia

# %%
dias = escala_instrumental.index
pessoas = escala_instrumental.columns
disponibilidade = escala_instrumental.copy()

# Número de dias a considerar antes e depois, incluindo o dia atual
n_dias = 4

# Percorrer cada pessoa
for pessoa in pessoas:
    # Percorrer cada dia
    for dia_index in range(len(dias)):
        exceed_limit = False
        
        # Verificar todos os intervalos de 4 dias dentro do raio de 4 dias ao redor do dia atual
        for start in range(-n_dias, 0):
            soma_dias = 0
            for k in range(4):
                if 0 <= dia_index + start + k < len(dias):
                    soma_dias += escala_instrumental.loc[dias[dia_index + start + k], pessoa]

            # Se a soma dos valores em qualquer intervalo de 4 dias exceder o limite
            if soma_dias >= DPM.loc[pessoa, 'Quantidade']:
                exceed_limit = True
        
        # Atualizar disponibilidade se nenhum intervalo excedeu o limite
        if not exceed_limit:
            disponibilidade.loc[dias[dia_index], pessoa] = 1

disponibilidade
# Out:
# Pessoas     Ariane  Bernardo  Dani  Daniel  Enzo  Everlyn  Gabriel  Henrique  \
# Dias
# 08_06_2024       1         1     1       0     1        1        1         1
# 15_06_2024       1         1     1       1     1        1        1         1
# 22_06_2024       1         1     1       1     0        1        0         1
# 29_06_2024       1         0     1       0     1        1        0         0
# 06_07_2024       1         1     1       0     0        1        1         1
# 13_07_2024       1         1     1       1     0        1        1         0
# 20_07_2024       1         0     1       1     0        1        0         1
# 27_07_2024       1         0     1       0     1        1        0         0
# 03_08_2024       1         0     1       0     1        1        0         1
# 10_08_2024       1         1     1       1     0        1        1         0
# 17_08_2024       1         1     1       1     0        1        0         1
# 24_08_2024       1         1     1       0     1        1        1         0
# 31_08_2024       1         1     1       0     1        1        0         1
#
# Pessoas     Israel  Júlia  Lucas  Marcela  Mauri  Osvaldo  Rafael  Ricardo  \
# Dias
# 08_06_2024       1      1      1        1      1        1       1        1
# 15_06_2024       0      1      1        1      1        0       0        0
# 22_06_2024       1      1      1        1      1        0       1        1
# 29_06_2024       0      1      1        1      1        1       1        0
# 06_07_2024       1      1      1        0      1        1       0        0
# 13_07_2024       0      1      1        0      1        0       0        1
# 20_07_2024       0      1      0        1      1        0       1        0
# 27_07_2024       1      1      1        0      1        1       1        0
# 03_08_2024       1      1      0        1      1        0       0        1
# 10_08_2024       1      1      1        0      1        1       0        0
# 17_08_2024       0      1      0        1      1        0       1        1
# 24_08_2024       1      1      0        0      1        0       1        0
# 31_08_2024       1      1      1        0      1        1       0        0
#
# Pessoas     Tassi  Vinicius
# Dias
# 08_06_2024      1         1
# 15_06_2024      1         1
# 22_06_2024      1         0
# 29_06_2024      1         1
# 06_07_2024      1         0
# 13_07_2024      1         0
# 20_07_2024      1         0
# 27_07_2024      1         1
# 03_08_2024      1         1
# 10_08_2024      1         0
# 17_08_2024      1         0
# 24_08_2024      1         1
# 31_08_2024      1         1
